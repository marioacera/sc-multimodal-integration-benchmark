# %%
import numpy as np
import scanpy as sc
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl

from matplotlib import rcParams
rcParams['pdf.fonttype'] = 42 # enables correct plotting of text
rcParams['figure.figsize'] = (7,7)

import random
import tensorflow as tf

seed = 42


random.seed(seed)
np.random.seed(seed)
tf.random.set_seed(seed)


# Import deepscore model # Add deepscore folder to path
from deepscore import deepscore 
import pickle

# %%
# cell_type = 'cell_type'

ref_py = sc.read('/home/macera/Documentos/CZI/MANUSCRIPT_PREP/REVIEWS/external_data/heart/reference.h5ad')

# %%
# ref_py.layers['counts'] = ref_py.X.copy()

ref_py.var['ENSG'] = ref_py.var.index.copy()
# ref_py.var.index = ref_py.var['feature_name'].copy()

# %%
ref_py.X.data
# Out:
# array([1., 1., 1., ..., 1., 2., 1.], dtype=float32)

# %%
# -*- coding: utf-8 -*-
from pathlib import Path
import os
import pickle
import scanpy as sc
import numpy as np
import pandas as pd

# ----------------------------
# Config
# ----------------------------
OVERLAPPING = False  # (unused placeholder)
COMPUTE = False

IN_ADATA = ref_py  # <-- assumes you already have an AnnData named ref_py in memory
CELLTYPE_KEY = "cell_type"
SUBSTATE_KEY = "cell_state"

OUT_SUBSETS = Path("objects/reference_subset_clean")
OUT_MARKERS = Path("markers_ds")



OUT_SUBSETS.mkdir(parents=True, exist_ok=True)
OUT_MARKERS.mkdir(parents=True, exist_ok=True)

# ----------------------------
# (0) Make sure X is normalized only if needed
#     If your on-disk subsets should be raw counts, skip this block and write raw.
#     Otherwise keep it, but then you can skip re-normalization later.
# ----------------------------
IN_ADATA.X = IN_ADATA.X.copy()
sc.pp.normalize_total(IN_ADATA, target_sum=1e4)
sc.pp.log1p(IN_ADATA)

# ----------------------------
# (1) Save per-cell_type subsets
# ----------------------------
cell_types = IN_ADATA.obs[CELLTYPE_KEY].unique().tolist()
for ct in cell_types:
    safe = ct.replace("/", "_")
    adata_ct = IN_ADATA[IN_ADATA.obs[CELLTYPE_KEY] == ct].copy()
    adata_ct.write(OUT_SUBSETS / f"{safe}.h5ad", compression="gzip")

# ----------------------------
# (2) Identify types with only a single substate
# ----------------------------
single_cat_ct = []
for ct in cell_types:
    safe = ct.replace("/", "_")
    adata_ct = sc.read(OUT_SUBSETS / f"{safe}.h5ad")
    n_states = adata_ct.obs[SUBSTATE_KEY].nunique()
    if n_states == 1:
        print(f"{safe}: Single category")
        single_cat_ct.append(ct)

multi_state_ct = [ct for ct in cell_types if ct not in single_cat_ct]

# ----------------------------
# (3) For each multi-state cell_type, run DE across substates
# ----------------------------
if COMPUTE:
    for ct in multi_state_ct:
        safe = ct.replace("/", "_")

        markers_filename = f"heart_cell_state_{safe}"

        if os.path.exists(markers_filename):
            pass
        else:
            adata_ct = sc.read(OUT_SUBSETS / f"{safe}.h5ad").copy()

            # Keep minimal QC (assumes counts or already logged — both are fine for wilcoxon w/ use_raw=False)
            sc.pp.filter_cells(adata_ct, min_counts=3)
            sc.pp.filter_genes(adata_ct, min_counts=3)

            # If files are raw counts, normalize+log here. If already normalized+logged, you may skip.
            sc.pp.normalize_total(adata_ct, target_sum=1e4)
            sc.pp.log1p(adata_ct)

            # Ensure grouping column is categorical and has >1 groups
            adata_ct.obs[SUBSTATE_KEY] = adata_ct.obs[SUBSTATE_KEY].astype("category")
            if adata_ct.obs[SUBSTATE_KEY].nunique() < 2:
                print(f"{safe}: <2 groups after filtering; skipping.")
                continue

            # Wilcoxon DE across substates (ties correction on)
            sc.tl.rank_genes_groups(
                adata_ct,
                groupby=SUBSTATE_KEY,
                method="wilcoxon",
                use_raw=False,
                tie_correct=True,
                n_genes=adata_ct.n_vars  # return full ranking
            )

            ranked = adata_ct.uns["rank_genes_groups"].copy()
            markers_filename = f"heart_cell_state_{safe}"
            with open(OUT_MARKERS / f"{markers_filename}.pickle", "wb") as handle:
                pickle.dump(ranked, handle, protocol=pickle.HIGHEST_PROTOCOL)

            print(f"{safe}: wrote {OUT_MARKERS / f'{markers_filename}.pickle'}")
# Out:
# WARNING: adata.X seems to be already log-transformed.
# Endothelial cell: wrote markers_ds/heart_cell_state_Endothelial cell.pickle
# WARNING: adata.X seems to be already log-transformed.
# Mural cell: wrote markers_ds/heart_cell_state_Mural cell.pickle
# WARNING: adata.X seems to be already log-transformed.
# Fibroblast: wrote markers_ds/heart_cell_state_Fibroblast.pickle
# WARNING: adata.X seems to be already log-transformed.
# Atrial Cardiomyocyte: wrote markers_ds/heart_cell_state_Atrial Cardiomyocyte.pickle
# WARNING: adata.X seems to be already log-transformed.
# Ventricular Cardiomyocyte: wrote markers_ds/heart_cell_state_Ventricular Cardiomyocyte.pickle

# %%
adata =  sc.read('/home/macera/Documentos/CZI/MANUSCRIPT_PREP/REVIEWS/external_data/heart/query.h5ad')

ds_hca = pd.read_csv(f'csv/Deepscore_HCA_l1_HEART.csv', index_col=0)

adata.obs['Deepscore_HCA_l1'] = ds_hca['Deepscore_HCA'].astype('category')
adata.obs['Deepscore_HCA_l1_score'] = ds_hca['Deepscore_HCA_score'].astype('category')

# %%
# In[33]:
try:
    os.mkdir(f'objects/QUERY_Heart_subset/')
except:
    print('Directory for subset saving already exists')


for i in adata.obs['Deepscore_HCA_l1'].unique():
    print(i)
    a = i.replace('/','_')
    # if os.path.exists(f'objects/reference_subset/{a}.h5ad') == False:
    adata[adata.obs['Deepscore_HCA_l1'].isin([i])].write(f'objects/QUERY_Heart_subset/{a}.h5ad', compression='gzip')
# Out:
# Directory for subset saving already exists
# Endothelial cell
# Mural cell
# Fibroblast
# Ventricular Cardiomyocyte
# Atrial Cardiomyocyte

# %%
adata.obs['cell_type'].unique()
# Out:
# ['Endothelial cell', 'Mural cell', 'Fibroblast', 'Ventricular Cardiomyocyte', 'Atrial Cardiomyocyte']
# Categories (5, object): ['Atrial Cardiomyocyte', 'Ventricular Cardiomyocyte', 'Fibroblast', 'Endothelial cell', 'Mural cell']

# %%
cell_type_list= ['Endothelial cell', 'Mural cell', 'Fibroblast', 'Ventricular Cardiomyocyte', 'Atrial Cardiomyocyte']

# %%
import os
n_markers = 300
cell_type = 'cell_state'

cell_type_list= ['Endothelial cell', 'Mural cell', 'Fibroblast', 'Ventricular Cardiomyocyte', 'Atrial Cardiomyocyte']


for i in cell_type_list:
    a = i.replace('/','_')
    if os.path.exists(f'csv/Deepscore_HCA_l3_{a}_CLEAN.csv'):
        print(f'{a} already exists!')
    else:
        ref_py = sc.read(f'objects/reference_subset_clean/{a}.h5ad')
        adata = sc.read(f'objects/QUERY_Heart_subset/{a}.h5ad', compression='gzip')

        sc.pp.normalize_total(adata, target_sum=1e4)
        sc.pp.log1p(adata)

        markers_filename = f"heart_cell_state_{a}"        # Identify differentially expressed genes between cell types

        with open(f'markers_ds/{markers_filename}.pickle', 'rb') as handle:
            ranked_genes_populations = pickle.load(handle) 

        # Step 1: Create a dictionary to store markers for each subset
        subset_markers_dict = {}

        # Step 2: Store markers for each subset
        for subset in ref_py.obs[cell_type].unique():
            subset_markers = ranked_genes_populations['names'][subset]
            subset_markers = [gene for gene in subset_markers if gene in adata.var.index]
            subset_markers_dict[subset] = set(subset_markers[:n_markers+100])

        # Step 3: Identify overlapping markers
        overlapping_markers = set()
        for subset, markers in subset_markers_dict.items():
            for other_subset, other_markers in subset_markers_dict.items():
                if subset != other_subset:
                    overlapping_markers.update(markers.intersection(other_markers))

        # Step 4: Select markers for each subset, excluding overlapping markers
        marker_dict = {}
        for subset, markers in subset_markers_dict.items():
            unique_markers = [marker for marker in markers if marker not in overlapping_markers]
            marker_dict[subset] = unique_markers[:n_markers]  # Select up to 200 unique markers
            # print(subset,len(unique_markers[:n_markers]))
        selected_markers = [marker for subset in marker_dict for marker in marker_dict[subset]]

        # print(selected_markers)



        # Subset the data to the selected markers
        ref_py = ref_py[:, list(selected_markers)].copy()
        adata = adata[:, list(selected_markers)].copy()


        sc.pp.scale(ref_py)
        sc.pp.scale(adata) 

        ref_py.obs[cell_type] = ref_py.obs[cell_type].tolist()
        len(ref_py.obs[cell_type].unique())

        def scheduler(epoch, lr):
            if epoch < 10:
                return lr
            else:
                return lr * tf.math.exp(-0.1)


        n_feat = ref_py.shape[1]
        n_labs = len(ref_py.obs[cell_type].unique())

        ds = deepscore.DeepScore(hidden_nodes=[512, 256],
                    n_features=n_feat, 
                    n_labels=n_labs,
                    epochs=30,
                    batch_size=128, 
                    activation="relu", 
                    dropout=True, 
                    dropout_rate=0.3,
                    batchnorm=True, 
                    lr=0.001,
                    weight_reg=True)

        os.environ["TF_GPU_ALLOCATOR"]="cuda_malloc_async"

        ds.set_reference(ref_py, label_by=cell_type, test_prop=0.1)

        ds.train(earlystopping=True, patience=10, lr_scheduler=scheduler,)

        prob_df, adata = ds.annotate(adata, pred_key='Deepscore_HCA',Unclassified = False,return_pred_matrix=True)

        adata.obs[['Deepscore_HCA','Deepscore_HCA_score']].to_csv(f'csv/Deepscore_HCA_l3_{a}.csv')

        prob_df.to_csv(f'csv/prob_matrix/Deepscore_HCA_l3_{a}.csv')
# Out:
# Model: "deepscore"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (Batch  (None, 1653)              6612
#  Normalization)
#
#  dense512 (Dense)            (None, 512)               846848
#
#  dropout (Dropout)           (None, 512)               0
#
#  batch_normalization_1 (Bat  (None, 512)               2048
#  chNormalization)
#
#  dense256 (Dense)            (None, 256)               131328
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  batch_normalization_2 (Bat  (None, 256)               1024
#  chNormalization)
#
#  output (Dense)              (None, 8)                 2056
#
# =================================================================
# Total params: 989916 (3.78 MB)
# Trainable params: 985074 (3.76 MB)
# Non-trainable params: 4842 (18.91 KB)
# _________________________________________________________________
# Epoch 1/30
# 318/318 [==============================] - 4s 11ms/step - loss: 0.9609 - categorical_accuracy: 0.6588 - val_loss: 0.7361 - val_categorical_accuracy: 0.7314 - lr: 0.0010
# Epoch 2/30
# 318/318 [==============================] - 3s 10ms/step - loss: 0.6950 - categorical_accuracy: 0.7419 - val_loss: 0.7270 - val_categorical_accuracy: 0.7354 - lr: 0.0010
# Epoch 3/30
# 318/318 [==============================] - 3s 10ms/step - loss: 0.6026 - categorical_accuracy: 0.7754 - val_loss: 0.7621 - val_categorical_accuracy: 0.7281 - lr: 0.0010
# Epoch 4/30
# 318/318 [==============================] - 3s 10ms/step - loss: 0.5106 - categorical_accuracy: 0.8098 - val_loss: 0.8128 - val_categorical_accuracy: 0.7254 - lr: 0.0010
# Epoch 5/30
# 318/318 [==============================] - 3s 11ms/step - loss: 0.4150 - categorical_accuracy: 0.8453 - val_loss: 0.8916 - val_categorical_accuracy: 0.7163 - lr: 0.0010
# Epoch 6/30
# 318/318 [==============================] - 3s 10ms/step - loss: 0.3210 - categorical_accuracy: 0.8823 - val_loss: 1.0041 - val_categorical_accuracy: 0.7103 - lr: 0.0010
# Epoch 7/30
# 318/318 [==============================] - 3s 11ms/step - loss: 0.2652 - categorical_accuracy: 0.9027 - val_loss: 1.1032 - val_categorical_accuracy: 0.7061 - lr: 0.0010
# Epoch 8/30
# 318/318 [==============================] - 3s 11ms/step - loss: 0.2398 - categorical_accuracy: 0.9123 - val_loss: 1.1292 - val_categorical_accuracy: 0.7030 - lr: 0.0010
# Epoch 9/30
# 318/318 [==============================] - 3s 11ms/step - loss: 0.2057 - categorical_accuracy: 0.9245 - val_loss: 1.1897 - val_categorical_accuracy: 0.7063 - lr: 0.0010
# Epoch 10/30
# 318/318 [==============================] - 3s 11ms/step - loss: 0.2062 - categorical_accuracy: 0.9257 - val_loss: 1.2594 - val_categorical_accuracy: 0.7070 - lr: 0.0010
# Epoch 11/30
# 318/318 [==============================] - 3s 11ms/step - loss: 0.1695 - categorical_accuracy: 0.9389 - val_loss: 1.2897 - val_categorical_accuracy: 0.7006 - lr: 9.0484e-04
# Epoch 12/30
# 318/318 [==============================] - 3s 11ms/step - loss: 0.1448 - categorical_accuracy: 0.9484 - val_loss: 1.2961 - val_categorical_accuracy: 0.7012 - lr: 8.1873e-04
#
# Evaluating model performance on unseen data (test data):
#
# 40/40 [==============================] - 0s 2ms/step - loss: 1.3929 - categorical_accuracy: 0.6856
#
# test loss: 1.39286, test accuracy:'               '0.68562
# 623/623 [==============================] - 1s 2ms/step
# Model: "deepscore"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization_3 (Bat  (None, 1646)              6584
#  chNormalization)
#
#  dense512 (Dense)            (None, 512)               843264
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  batch_normalization_4 (Bat  (None, 512)               2048
#  chNormalization)
#
#  dense256 (Dense)            (None, 256)               131328
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  batch_normalization_5 (Bat  (None, 256)               1024
#  chNormalization)
#
#  output (Dense)              (None, 6)                 1542
#
# =================================================================
# Total params: 985790 (3.76 MB)
# Trainable params: 980962 (3.74 MB)
# Non-trainable params: 4828 (18.86 KB)
# _________________________________________________________________
# Epoch 1/30
# 422/422 [==============================] - 6s 11ms/step - loss: 0.5178 - categorical_accuracy: 0.8316 - val_loss: 0.4000 - val_categorical_accuracy: 0.8694 - lr: 0.0010
# Epoch 2/30
# 422/422 [==============================] - 4s 10ms/step - loss: 0.3446 - categorical_accuracy: 0.8782 - val_loss: 0.3892 - val_categorical_accuracy: 0.8678 - lr: 0.0010
# Epoch 3/30
# 422/422 [==============================] - 5s 11ms/step - loss: 0.2880 - categorical_accuracy: 0.8951 - val_loss: 0.4258 - val_categorical_accuracy: 0.8594 - lr: 0.0010
# Epoch 4/30
# 422/422 [==============================] - 4s 11ms/step - loss: 0.2352 - categorical_accuracy: 0.9133 - val_loss: 0.4670 - val_categorical_accuracy: 0.8603 - lr: 0.0010
# Epoch 5/30
# 422/422 [==============================] - 12s 28ms/step - loss: 0.1791 - categorical_accuracy: 0.9346 - val_loss: 0.5409 - val_categorical_accuracy: 0.8578 - lr: 0.0010
# Epoch 6/30
# 422/422 [==============================] - 12s 28ms/step - loss: 0.1411 - categorical_accuracy: 0.9483 - val_loss: 0.5907 - val_categorical_accuracy: 0.8467 - lr: 0.0010
# Epoch 7/30
# 422/422 [==============================] - 11s 26ms/step - loss: 0.1219 - categorical_accuracy: 0.9549 - val_loss: 0.6209 - val_categorical_accuracy: 0.8529 - lr: 0.0010
# Epoch 8/30
# 422/422 [==============================] - 11s 26ms/step - loss: 0.1157 - categorical_accuracy: 0.9584 - val_loss: 0.6458 - val_categorical_accuracy: 0.8508 - lr: 0.0010
# Epoch 9/30
# 422/422 [==============================] - 8s 19ms/step - loss: 0.1087 - categorical_accuracy: 0.9603 - val_loss: 0.6949 - val_categorical_accuracy: 0.8479 - lr: 0.0010
# Epoch 10/30
# 422/422 [==============================] - 5s 12ms/step - loss: 0.0980 - categorical_accuracy: 0.9647 - val_loss: 0.6824 - val_categorical_accuracy: 0.8497 - lr: 0.0010
# Epoch 11/30
# 422/422 [==============================] - 5s 11ms/step - loss: 0.0850 - categorical_accuracy: 0.9681 - val_loss: 0.7167 - val_categorical_accuracy: 0.8492 - lr: 9.0484e-04
# Epoch 12/30
# 422/422 [==============================] - 4s 10ms/step - loss: 0.0737 - categorical_accuracy: 0.9728 - val_loss: 0.7359 - val_categorical_accuracy: 0.8471 - lr: 8.1873e-04
#
# Evaluating model performance on unseen data (test data):
#
# 52/52 [==============================] - 0s 2ms/step - loss: 0.7118 - categorical_accuracy: 0.8545
#
# test loss: 0.71177, test accuracy:'               '0.85455
# 292/292 [==============================] - 1s 2ms/step
# Model: "deepscore"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization_6 (Bat  (None, 1793)              7172
#  chNormalization)
#
#  dense512 (Dense)            (None, 512)               918528
#
#  dropout_4 (Dropout)         (None, 512)               0
#
#  batch_normalization_7 (Bat  (None, 512)               2048
#  chNormalization)
#
#  dense256 (Dense)            (None, 256)               131328
#
#  dropout_5 (Dropout)         (None, 256)               0
#
#  batch_normalization_8 (Bat  (None, 256)               1024
#  chNormalization)
#
#  output (Dense)              (None, 6)                 1542
#
# =================================================================
# Total params: 1061642 (4.05 MB)
# Trainable params: 1056520 (4.03 MB)
# Non-trainable params: 5122 (20.01 KB)
# _________________________________________________________________
# Epoch 1/30
# 557/557 [==============================] - 8s 14ms/step - loss: 0.7307 - categorical_accuracy: 0.7452 - val_loss: 0.5935 - val_categorical_accuracy: 0.7875 - lr: 0.0010
# Epoch 2/30
# 557/557 [==============================] - 16s 29ms/step - loss: 0.5415 - categorical_accuracy: 0.8031 - val_loss: 0.5997 - val_categorical_accuracy: 0.7876 - lr: 0.0010
# Epoch 3/30
# 557/557 [==============================] - 11s 19ms/step - loss: 0.4730 - categorical_accuracy: 0.8249 - val_loss: 0.6165 - val_categorical_accuracy: 0.7870 - lr: 0.0010
# Epoch 4/30
# 557/557 [==============================] - 6s 11ms/step - loss: 0.4010 - categorical_accuracy: 0.8525 - val_loss: 0.6621 - val_categorical_accuracy: 0.7834 - lr: 0.0010
# Epoch 5/30
# 557/557 [==============================] - 7s 12ms/step - loss: 0.3327 - categorical_accuracy: 0.8765 - val_loss: 0.7294 - val_categorical_accuracy: 0.7729 - lr: 0.0010
# Epoch 6/30
# 557/557 [==============================] - 7s 13ms/step - loss: 0.2880 - categorical_accuracy: 0.8932 - val_loss: 0.7542 - val_categorical_accuracy: 0.7682 - lr: 0.0010
# Epoch 7/30
# 557/557 [==============================] - 11s 20ms/step - loss: 0.2578 - categorical_accuracy: 0.9038 - val_loss: 0.8092 - val_categorical_accuracy: 0.7640 - lr: 0.0010
# Epoch 8/30
# 557/557 [==============================] - 13s 24ms/step - loss: 0.2362 - categorical_accuracy: 0.9133 - val_loss: 0.8593 - val_categorical_accuracy: 0.7606 - lr: 0.0010
# Epoch 9/30
# 557/557 [==============================] - 7s 13ms/step - loss: 0.2150 - categorical_accuracy: 0.9208 - val_loss: 0.8923 - val_categorical_accuracy: 0.7635 - lr: 0.0010
# Epoch 10/30
# 557/557 [==============================] - 7s 12ms/step - loss: 0.2088 - categorical_accuracy: 0.9240 - val_loss: 0.8793 - val_categorical_accuracy: 0.7648 - lr: 0.0010
# Epoch 11/30
# 557/557 [==============================] - 6s 11ms/step - loss: 0.1830 - categorical_accuracy: 0.9337 - val_loss: 0.9490 - val_categorical_accuracy: 0.7658 - lr: 9.0484e-04
#
# Evaluating model performance on unseen data (test data):
#
# 69/69 [==============================] - 0s 2ms/step - loss: 0.9028 - categorical_accuracy: 0.7663
#
# test loss: 0.90284, test accuracy:'               '0.76626
# 376/376 [==============================] - 1s 3ms/step
# Model: "deepscore"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization_9 (Bat  (None, 1200)              4800
#  chNormalization)
#
#  dense512 (Dense)            (None, 512)               614912
#
#  dropout_6 (Dropout)         (None, 512)               0
#
#  batch_normalization_10 (Ba  (None, 512)               2048
#  tchNormalization)
#
#  dense256 (Dense)            (None, 256)               131328
#
#  dropout_7 (Dropout)         (None, 256)               0
#
#  batch_normalization_11 (Ba  (None, 256)               1024
#  tchNormalization)
#
#  output (Dense)              (None, 4)                 1028
#
# =================================================================
# Total params: 755140 (2.88 MB)
# Trainable params: 751204 (2.87 MB)
# Non-trainable params: 3936 (15.38 KB)
# _________________________________________________________________
# Epoch 1/30
# 905/905 [==============================] - 11s 11ms/step - loss: 0.6015 - categorical_accuracy: 0.7626 - val_loss: 0.4815 - val_categorical_accuracy: 0.8034 - lr: 0.0010
# Epoch 2/30
# 905/905 [==============================] - 9s 10ms/step - loss: 0.4846 - categorical_accuracy: 0.8007 - val_loss: 0.4721 - val_categorical_accuracy: 0.8042 - lr: 0.0010
# Epoch 3/30
# 905/905 [==============================] - 9s 10ms/step - loss: 0.4460 - categorical_accuracy: 0.8174 - val_loss: 0.4677 - val_categorical_accuracy: 0.8050 - lr: 0.0010
# Epoch 4/30
# 905/905 [==============================] - 9s 10ms/step - loss: 0.4011 - categorical_accuracy: 0.8342 - val_loss: 0.4769 - val_categorical_accuracy: 0.8046 - lr: 0.0010
# Epoch 5/30
# 905/905 [==============================] - 9s 10ms/step - loss: 0.3610 - categorical_accuracy: 0.8522 - val_loss: 0.4969 - val_categorical_accuracy: 0.7986 - lr: 0.0010
# Epoch 6/30
# 905/905 [==============================] - 9s 10ms/step - loss: 0.3321 - categorical_accuracy: 0.8656 - val_loss: 0.5174 - val_categorical_accuracy: 0.7974 - lr: 0.0010
# Epoch 7/30
# 905/905 [==============================] - 9s 10ms/step - loss: 0.3056 - categorical_accuracy: 0.8769 - val_loss: 0.5310 - val_categorical_accuracy: 0.7965 - lr: 0.0010
# Epoch 8/30
# 905/905 [==============================] - 9s 10ms/step - loss: 0.2883 - categorical_accuracy: 0.8851 - val_loss: 0.5390 - val_categorical_accuracy: 0.7917 - lr: 0.0010
# Epoch 9/30
# 905/905 [==============================] - 9s 10ms/step - loss: 0.2751 - categorical_accuracy: 0.8899 - val_loss: 0.5541 - val_categorical_accuracy: 0.7931 - lr: 0.0010
# Epoch 10/30
# 905/905 [==============================] - 9s 10ms/step - loss: 0.2621 - categorical_accuracy: 0.8968 - val_loss: 0.5663 - val_categorical_accuracy: 0.7930 - lr: 0.0010
# Epoch 11/30
# 905/905 [==============================] - 9s 10ms/step - loss: 0.2393 - categorical_accuracy: 0.9067 - val_loss: 0.5874 - val_categorical_accuracy: 0.7937 - lr: 9.0484e-04
# Epoch 12/30
# 905/905 [==============================] - 9s 10ms/step - loss: 0.2181 - categorical_accuracy: 0.9150 - val_loss: 0.5938 - val_categorical_accuracy: 0.7924 - lr: 8.1873e-04
# Epoch 13/30
# 905/905 [==============================] - 9s 10ms/step - loss: 0.1976 - categorical_accuracy: 0.9235 - val_loss: 0.6355 - val_categorical_accuracy: 0.7920 - lr: 7.4082e-04
#
# Evaluating model performance on unseen data (test data):
#
# 112/112 [==============================] - 0s 3ms/step - loss: 0.6286 - categorical_accuracy: 0.7919
#
# test loss: 0.62862, test accuracy:'               '0.79191
# 355/355 [==============================] - 1s 2ms/step
# Model: "deepscore"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization_12 (Ba  (None, 1200)              4800
#  tchNormalization)
#
#  dense512 (Dense)            (None, 512)               614912
#
#  dropout_8 (Dropout)         (None, 512)               0
#
#  batch_normalization_13 (Ba  (None, 512)               2048
#  tchNormalization)
#
#  dense256 (Dense)            (None, 256)               131328
#
#  dropout_9 (Dropout)         (None, 256)               0
#
#  batch_normalization_14 (Ba  (None, 256)               1024
#  tchNormalization)
#
#  output (Dense)              (None, 4)                 1028
#
# =================================================================
# Total params: 755140 (2.88 MB)
# Trainable params: 751204 (2.87 MB)
# Non-trainable params: 3936 (15.38 KB)
# _________________________________________________________________
# Epoch 1/30
# 165/165 [==============================] - 3s 11ms/step - loss: 0.7485 - categorical_accuracy: 0.7356 - val_loss: 0.5791 - val_categorical_accuracy: 0.7991 - lr: 0.0010
# Epoch 2/30
# 165/165 [==============================] - 2s 10ms/step - loss: 0.5000 - categorical_accuracy: 0.8152 - val_loss: 0.5473 - val_categorical_accuracy: 0.7956 - lr: 0.0010
# Epoch 3/30
# 165/165 [==============================] - 2s 10ms/step - loss: 0.4103 - categorical_accuracy: 0.8476 - val_loss: 0.5607 - val_categorical_accuracy: 0.7910 - lr: 0.0010
# Epoch 4/30
# 165/165 [==============================] - 2s 10ms/step - loss: 0.3208 - categorical_accuracy: 0.8795 - val_loss: 0.6422 - val_categorical_accuracy: 0.7824 - lr: 0.0010
# Epoch 5/30
# 165/165 [==============================] - 2s 10ms/step - loss: 0.2434 - categorical_accuracy: 0.9104 - val_loss: 0.6984 - val_categorical_accuracy: 0.7722 - lr: 0.0010
# Epoch 6/30
# 165/165 [==============================] - 2s 10ms/step - loss: 0.1766 - categorical_accuracy: 0.9347 - val_loss: 0.7472 - val_categorical_accuracy: 0.7858 - lr: 0.0010
# Epoch 7/30
# 165/165 [==============================] - 2s 10ms/step - loss: 0.1298 - categorical_accuracy: 0.9534 - val_loss: 0.8265 - val_categorical_accuracy: 0.7786 - lr: 0.0010
# Epoch 8/30
# 165/165 [==============================] - 2s 10ms/step - loss: 0.1022 - categorical_accuracy: 0.9632 - val_loss: 0.9043 - val_categorical_accuracy: 0.7841 - lr: 0.0010
# Epoch 9/30
# 165/165 [==============================] - 2s 10ms/step - loss: 0.0929 - categorical_accuracy: 0.9669 - val_loss: 0.9752 - val_categorical_accuracy: 0.7833 - lr: 0.0010
# Epoch 10/30
# 165/165 [==============================] - 2s 10ms/step - loss: 0.0789 - categorical_accuracy: 0.9718 - val_loss: 0.9633 - val_categorical_accuracy: 0.7786 - lr: 0.0010
# Epoch 11/30
# 165/165 [==============================] - 2s 10ms/step - loss: 0.0630 - categorical_accuracy: 0.9783 - val_loss: 1.0296 - val_categorical_accuracy: 0.7803 - lr: 9.0484e-04
# Epoch 12/30
# 165/165 [==============================] - 2s 10ms/step - loss: 0.0503 - categorical_accuracy: 0.9834 - val_loss: 1.0928 - val_categorical_accuracy: 0.7786 - lr: 8.1873e-04
#
# Evaluating model performance on unseen data (test data):
#
# 21/21 [==============================] - 0s 3ms/step - loss: 1.0521 - categorical_accuracy: 0.7939
#
# test loss: 1.05213, test accuracy:'               '0.79386
# 150/150 [==============================] - 0s 2ms/step

# %%
# GRID SEARCH

"""
Auto-tuning wrapper for DeepScore per cell type.

- Reproducible: fixed seeds.
- Small, sensible hyperparameter grid.
- Picks best config per cell type using (val_acc, -val_loss, test_acc).
- Saves best Keras model and CSV outputs preserving your filenames.
"""
import os, pickle, json, time
import numpy as np
import scanpy as sc
import tensorflow as tf
from itertools import product
from copy import deepcopy

# --- Determinism (set this BEFORE creating any TF graph/model) ---
SEED = 0
os.environ["PYTHONHASHSEED"] = str(SEED)
os.environ["TF_DETERMINISTIC_OPS"] = "1"
# Optional: if you really need the async allocator, set it BEFORE TF is imported.
os.environ["TF_GPU_ALLOCATOR"] = "cuda_malloc_async"
np.random.seed(SEED)
tf.random.set_seed(SEED)

from deepscore import deepscore  # from your deepscore.py

# ---- Your inputs ----
n_markers = 300
cell_type = 'cell_state'
cell_type_list = [
    'Endothelial cell', 'Mural cell', 'Fibroblast',
    'Ventricular Cardiomyocyte', 'Atrial Cardiomyocyte'
]

# --- LR schedulers ---
def lr_none(epoch, lr):      # identity
    return lr

def lr_exp_decay(epoch, lr): # gentle exponential decay after warmup
    if epoch < 10:
        return lr
    return lr * tf.math.exp(-0.08)

LR_SCHEDULERS = {
    "none": lr_none,
    "exp_decay": lr_exp_decay,
}

# --- Small hyperparameter search space (kept modest to avoid long runs) ---
GRID = {
    "hidden_nodes": [
        (512, 256),
        (256, 128),
        (512, 256, 128),
    ],
    "dropout": [True],
    "dropout_rate": [0.2, 0.3, 0.4],
    "batchnorm": [True],
    "lr": [1e-3, 5e-4],
    "l2": [0.0, 1e-4, 1e-3],   # L2 via kernel_regularizer
    "weight_reg": [True, False],# max-norm on weights (see class ctor)
    "batch_size": [64, 128],
    "epochs": [30, 60],
    "patience": [5, 10],
    "val_split": [0.1],        # keep stable
    "test_prop": [0.1],        # keep enough test for evaluation
    "lr_sched_name": ["none", "exp_decay"],
}

def grid_iter(grid_dict):
    keys = list(grid_dict.keys())
    for values in product(*[grid_dict[k] for k in keys]):
        yield dict(zip(keys, values))

# --- Utilities ---
def select_markers_for_subset(ref_py, adata, ranked_genes_populations, label_key, n_markers=300, pad=100):
    """Build the non-overlapping marker set per cell-state and subset both AnnDatas."""
    subset_markers_dict = {}
    for subset in ref_py.obs[label_key].unique():
        subset_markers = ranked_genes_populations['names'][subset]
        subset_markers = [g for g in subset_markers if g in adata.var.index]
        subset_markers_dict[subset] = set(subset_markers[:n_markers + pad])

    # remove overlapping markers across subsets
    overlapping = set()
    subs = list(subset_markers_dict.keys())
    for i, s in enumerate(subs):
        for t in subs[i+1:]:
            overlapping.update(subset_markers_dict[s].intersection(subset_markers_dict[t]))

    marker_dict = {}
    for subset, markers in subset_markers_dict.items():
        uniq = [m for m in markers if m not in overlapping]
        marker_dict[subset] = uniq[:n_markers]
    selected = [m for subset in marker_dict for m in marker_dict[subset]]
    return list(selected)

def evaluate_config(ref_py, adata, label_key, cfg):
    """
    Train one DeepScore config and return metrics for ranking.
    Returns (summary_dict, ds) so the caller can persist the winning model.
    """
    # Re-seed before each trial
    np.random.seed(SEED); tf.random.set_seed(SEED)

    n_feat = ref_py.shape[1]
    n_labs = len(ref_py.obs[label_key].unique())
    ds = deepscore.DeepScore(
        hidden_nodes=list(cfg["hidden_nodes"]),
        n_features=n_feat,
        n_labels=n_labs,
        epochs=int(cfg["epochs"]),
        batch_size=int(cfg["batch_size"]),
        activation="relu",
        dropout=bool(cfg["dropout"]),
        dropout_rate=float(cfg["dropout_rate"]),
        batchnorm=bool(cfg["batchnorm"]),
        lr=float(cfg["lr"]),
        weight_reg=bool(cfg["weight_reg"]),
        l1=0.0,
        l2=float(cfg["l2"]),
    )  # constructor supports these args and metrics include CategoricalAccuracy. :contentReference[oaicite:2]{index=2}

    # internal train/test split occurs here
    ds.set_reference(ref_py, label_by=label_key, test_prop=float(cfg["test_prop"]))  # :contentReference[oaicite:3]{index=3}

    sched = LR_SCHEDULERS[cfg["lr_sched_name"]]
    # Train; we’ll read back the last val metrics from History
    history = ds.train(
        val_split=float(cfg["val_split"]),
        earlystopping=True,
        lr_scheduler=sched,
        patience=int(cfg["patience"]),
        training_report=True,   # returns [loss, acc] on test
    )
    # training_report returns "evaluation" = [test_loss, test_acc] according to the code. :contentReference[oaicite:4]{index=4}
    test_loss, test_acc = float(history[0]), float(history[1])

    # Try to access last epoch validation metrics via model.history if present.
    # Keras History is not returned directly by train(), but callbacks store logs.
    # We’ll approximate using TensorBoard not being directly accessible; instead,
    # rely on test metrics for ranking and use val_split stability.
    # If you'd like strict val metrics, consider instrumenting deepscore.train to return history.history.

    summary = {
        "val_acc": None,      # placeholder (not directly exposed)
        "val_loss": None,     # placeholder
        "test_acc": test_acc,
        "test_loss": test_loss,
    }
    return summary, ds

def better_than(a, b):
    """Comparator: prioritize higher test_acc; tie-breaker lower test_loss."""
    if b is None: 
        return True
    if a["test_acc"] > b["test_acc"]: 
        return True
    if a["test_acc"] == b["test_acc"] and a["test_loss"] < b["test_loss"]:
        return True
    return False

# --- Main loop over cell types ---
os.makedirs('csv', exist_ok=True)
os.makedirs('csv/prob_matrix', exist_ok=True)
os.makedirs('models', exist_ok=True)
os.makedirs('markers_ds', exist_ok=True)

results_all = []

for i in cell_type_list:
    a = i.replace('/','_')
    out_csv = f'csv/Deepscore_HCA_l3_{a}_CLEAN.csv'
    if os.path.exists(out_csv):
        print(f'{a} already exists!'); 
        continue

    # Load reference & query
    ref_py = sc.read(f'objects/reference_subset_clean/{a}.h5ad')
    adata  = sc.read(f'objects/QUERY_Heart_subset/{a}.h5ad', compression='gzip')

    # Basic preprocessing (as in your snippet)
    sc.pp.normalize_total(adata, target_sum=1e4); sc.pp.log1p(adata)

    markers_filename = f"heart_cell_state_{a}"
    with open(f'markers_ds/{markers_filename}.pickle', 'rb') as handle:
        ranked_genes_populations = pickle.load(handle)

    # Build unique marker panel & subset
    selected_markers = select_markers_for_subset(
        ref_py, adata, ranked_genes_populations, label_key=cell_type,
        n_markers=n_markers, pad=100
    )
    ref_use = ref_py[:, selected_markers].copy()
    ad_use  = adata[:,  selected_markers].copy()

    # Scale (to stabilize optimization)
    sc.pp.scale(ref_use); sc.pp.scale(ad_use)

    # Ensure label dtype
    ref_use.obs[cell_type] = ref_use.obs[cell_type].astype(str)

    # --- Hyperparameter search ---
    best_metrics = None
    best_cfg = None
    best_model = None

    t0 = time.time()
    tried = 0
    for cfg in grid_iter(GRID):
        tried += 1
        cfg = deepcopy(cfg)
        metrics, ds = evaluate_config(ref_use, ad_use, cell_type, cfg)
        row = dict(cell_type=a, tried=tried, **cfg, **metrics)
        results_all.append(row)
        print(f"[{a}] Trial {tried}: test_acc={metrics['test_acc']:.4f}, test_loss={metrics['test_loss']:.4f}")

        if better_than(metrics, best_metrics):
            best_metrics = metrics
            best_cfg = deepcopy(cfg)
            best_model = ds  # keep the trained model of the best config so far

    elapsed = time.time() - t0
    print(f"[{a}] best_cfg: {json.dumps(best_cfg, default=str)} | metrics: {best_metrics} | {elapsed/60:.1f} min")

    # --- Final annotation with the best model ---
    # Use the best trained model directly to annotate the query
    prob_df, ad_scored = best_model.annotate(ad_use, pred_key='Deepscore_HCA',
                                             Unclassified=False, return_pred_matrix=True)  # :contentReference[oaicite:5]{index=5}

    # Save outputs (your original filenames)
    ad_scored.obs[['Deepscore_HCA','Deepscore_HCA_score']].to_csv(f'csv/Deepscore_HCA_l3_{a}.csv')
    prob_df.to_csv(f'csv/prob_matrix/Deepscore_HCA_l3_{a}.csv')

    # Optional: persist best Keras model for this cell type
    model_path = f"models/deepscore_best_{a}.keras"
    best_model.model.save(model_path)

# --- Save the search log (all cell types) ---
import pandas as pd
pd.DataFrame(results_all).to_csv("csv/deepscore_hparam_search_log.csv", index=False)
print("Search complete. Log written to csv/deepscore_hparam_search_log.csv")
# Out:
# Model: "deepscore"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (Batch  (None, 1653)              6612
#  Normalization)
#
#  dense512 (Dense)            (None, 512)               846848
#
#  dropout (Dropout)           (None, 512)               0
#
#  batch_normalization_1 (Bat  (None, 512)               2048
#  chNormalization)
#
#  dense256 (Dense)            (None, 256)               131328
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  batch_normalization_2 (Bat  (None, 256)               1024
#  chNormalization)
#
#  output (Dense)              (None, 8)                 2056
#
# =================================================================
# Total params: 989916 (3.78 MB)
# Trainable params: 985074 (3.76 MB)
# Non-trainable params: 4842 (18.91 KB)
# _________________________________________________________________
# 2025-08-21 19:00:11.415541: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 298306992 exceeds 10% of free system memory.
# 2025-08-21 19:00:11.561069: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 268473648 exceeds 10% of free system memory.
# Epoch 1/30
# 2025-08-21 19:00:11.908546: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 268473648 exceeds 10% of free system memory.
# 635/635 [==============================] - 9s 12ms/step - loss: 0.9300 - categorical_accuracy: 0.6672 - val_loss: 0.7522 - val_categorical_accuracy: 0.7292 - lr: 0.0010
# Epoch 2/30
# 635/635 [==============================] - 8s 12ms/step - loss: 0.6908 - categorical_accuracy: 0.7432 - val_loss: 0.7567 - val_categorical_accuracy: 0.7201 - lr: 0.0010
# Epoch 3/30
# 635/635 [==============================] - 7s 11ms/step - loss: 0.5886 - categorical_accuracy: 0.7799 - val_loss: 0.8039 - val_categorical_accuracy: 0.7188 - lr: 0.0010
# Epoch 4/30
# 635/635 [==============================] - 7s 11ms/step - loss: 0.4939 - categorical_accuracy: 0.8141 - val_loss: 0.9064 - val_categorical_accuracy: 0.7074 - lr: 0.0010
# Epoch 5/30
# 635/635 [==============================] - 7s 11ms/step - loss: 0.4157 - categorical_accuracy: 0.8439 - val_loss: 0.9933 - val_categorical_accuracy: 0.6966 - lr: 0.0010
# Epoch 6/30
# 635/635 [==============================] - 7s 11ms/step - loss: 0.3754 - categorical_accuracy: 0.8598 - val_loss: 1.0142 - val_categorical_accuracy: 0.6882 - lr: 0.0010
#
# Evaluating model performance on unseen data (test data):
#
# 79/79 [==============================] - 0s 2ms/step - loss: 1.0508 - categorical_accuracy: 0.6894
#
# test loss: 1.05083, test accuracy:'               '0.68941
# [Endothelial cell] Trial 1: test_acc=0.6894, test_loss=1.0508
# Model: "deepscore"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization_3 (Bat  (None, 1653)              6612
#  chNormalization)
#
#  dense512 (Dense)            (None, 512)               846848
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  batch_normalization_4 (Bat  (None, 512)               2048
#  chNormalization)
#
#  dense256 (Dense)            (None, 256)               131328
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  batch_normalization_5 (Bat  (None, 256)               1024
#  chNormalization)
#
#  output (Dense)              (None, 8)                 2056
#
# =================================================================
# Total params: 989916 (3.78 MB)
# Trainable params: 985074 (3.76 MB)
# Non-trainable params: 4842 (18.91 KB)
# _________________________________________________________________
# 2025-08-21 19:00:56.750868: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 298306992 exceeds 10% of free system memory.
# 2025-08-21 19:00:56.864414: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 268473648 exceeds 10% of free system memory.
# Epoch 1/30
# 635/635 [==============================] - 8s 11ms/step - loss: 0.9239 - categorical_accuracy: 0.6662 - val_loss: 0.7459 - val_categorical_accuracy: 0.7272 - lr: 0.0010
# Epoch 2/30
# 635/635 [==============================] - 7s 11ms/step - loss: 0.6899 - categorical_accuracy: 0.7428 - val_loss: 0.7614 - val_categorical_accuracy: 0.7210 - lr: 0.0010
# Epoch 3/30
# 635/635 [==============================] - 7s 11ms/step - loss: 0.5904 - categorical_accuracy: 0.7792 - val_loss: 0.7922 - val_categorical_accuracy: 0.7119 - lr: 0.0010
# Epoch 4/30
# 635/635 [==============================] - 7s 11ms/step - loss: 0.4916 - categorical_accuracy: 0.8154 - val_loss: 0.9023 - val_categorical_accuracy: 0.7001 - lr: 0.0010
# Epoch 5/30
# 635/635 [==============================] - 7s 11ms/step - loss: 0.4130 - categorical_accuracy: 0.8449 - val_loss: 0.9844 - val_categorical_accuracy: 0.6948 - lr: 0.0010
# Epoch 6/30
# 635/635 [==============================] - 7s 11ms/step - loss: 0.3722 - categorical_accuracy: 0.8608 - val_loss: 1.0376 - val_categorical_accuracy: 0.6944 - lr: 0.0010
#
# Evaluating model performance on unseen data (test data):
#
# 79/79 [==============================] - 0s 2ms/step - loss: 1.0870 - categorical_accuracy: 0.6874
#
# test loss: 1.08696, test accuracy:'               '0.68741
# [Endothelial cell] Trial 2: test_acc=0.6874, test_loss=1.0870
# Model: "deepscore"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization_6 (Bat  (None, 1653)              6612
#  chNormalization)
#
#  dense512 (Dense)            (None, 512)               846848
#
#  dropout_4 (Dropout)         (None, 512)               0
#
#  batch_normalization_7 (Bat  (None, 512)               2048
#  chNormalization)
#
#  dense256 (Dense)            (None, 256)               131328
#
#  dropout_5 (Dropout)         (None, 256)               0
#
#  batch_normalization_8 (Bat  (None, 256)               1024
#  chNormalization)
#
#  output (Dense)              (None, 8)                 2056
#
# =================================================================
# Total params: 989916 (3.78 MB)
# Trainable params: 985074 (3.76 MB)
# Non-trainable params: 4842 (18.91 KB)
# _________________________________________________________________
# Epoch 1/30
# 635/635 [==============================] - 8s 11ms/step - loss: 0.9235 - categorical_accuracy: 0.6656 - val_loss: 0.7563 - val_categorical_accuracy: 0.7294 - lr: 0.0010
# Epoch 2/30
# 635/635 [==============================] - 7s 11ms/step - loss: 0.6909 - categorical_accuracy: 0.7427 - val_loss: 0.7650 - val_categorical_accuracy: 0.7179 - lr: 0.0010
# Epoch 3/30
# 635/635 [==============================] - 7s 11ms/step - loss: 0.5925 - categorical_accuracy: 0.7770 - val_loss: 0.8117 - val_categorical_accuracy: 0.7179 - lr: 0.0010
# Epoch 4/30
# 635/635 [==============================] - 7s 11ms/step - loss: 0.4891 - categorical_accuracy: 0.8136 - val_loss: 0.9014 - val_categorical_accuracy: 0.7019 - lr: 0.0010
# Epoch 5/30
# 635/635 [==============================] - 7s 11ms/step - loss: 0.4208 - categorical_accuracy: 0.8432 - val_loss: 0.9837 - val_categorical_accuracy: 0.6935 - lr: 0.0010
# Epoch 6/30
# 635/635 [==============================] - 7s 11ms/step - loss: 0.3735 - categorical_accuracy: 0.8601 - val_loss: 1.0341 - val_categorical_accuracy: 0.6997 - lr: 0.0010
# Epoch 7/30
# 635/635 [==============================] - 7s 11ms/step - loss: 0.3365 - categorical_accuracy: 0.8751 - val_loss: 1.1009 - val_categorical_accuracy: 0.6886 - lr: 0.0010
# Epoch 8/30
# 635/635 [==============================] - 7s 11ms/step - loss: 0.3133 - categorical_accuracy: 0.8835 - val_loss: 1.1181 - val_categorical_accuracy: 0.6981 - lr: 0.0010
# Epoch 9/30
# 635/635 [==============================] - 7s 11ms/step - loss: 0.2828 - categorical_accuracy: 0.8959 - val_loss: 1.1997 - val_categorical_accuracy: 0.6846 - lr: 0.0010
# Epoch 10/30
# 635/635 [==============================] - 7s 11ms/step - loss: 0.2729 - categorical_accuracy: 0.9004 - val_loss: 1.1842 - val_categorical_accuracy: 0.6928 - lr: 0.0010
# Epoch 11/30
# 635/635 [==============================] - 7s 11ms/step - loss: 0.2674 - categorical_accuracy: 0.9031 - val_loss: 1.1743 - val_categorical_accuracy: 0.6937 - lr: 0.0010
#
# Evaluating model performance on unseen data (test data):
#
# 79/79 [==============================] - 0s 2ms/step - loss: 1.1908 - categorical_accuracy: 0.6828
#
# test loss: 1.19081, test accuracy:'               '0.68282
# [Endothelial cell] Trial 3: test_acc=0.6828, test_loss=1.1908
# Model: "deepscore"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization_9 (Bat  (None, 1653)              6612
#  chNormalization)
#
#  dense512 (Dense)            (None, 512)               846848
#
#  dropout_6 (Dropout)         (None, 512)               0
#
#  batch_normalization_10 (Ba  (None, 512)               2048
#  tchNormalization)
#
#  dense256 (Dense)            (None, 256)               131328
#
#  dropout_7 (Dropout)         (None, 256)               0
#
#  batch_normalization_11 (Ba  (None, 256)               1024
#  tchNormalization)
#
#  output (Dense)              (None, 8)                 2056
#
# =================================================================
# Total params: 989916 (3.78 MB)
# Trainable params: 985074 (3.76 MB)
# Non-trainable params: 4842 (18.91 KB)
# _________________________________________________________________
# Epoch 1/30
# 635/635 [==============================] - 8s 11ms/step - loss: 0.9190 - categorical_accuracy: 0.6677 - val_loss: 0.7505 - val_categorical_accuracy: 0.7298 - lr: 0.0010
# Epoch 2/30
# 635/635 [==============================] - 18s 29ms/step - loss: 0.6872 - categorical_accuracy: 0.7437 - val_loss: 0.7631 - val_categorical_accuracy: 0.7241 - lr: 0.0010
# Epoch 3/30
# 635/635 [==============================] - 17s 27ms/step - loss: 0.5928 - categorical_accuracy: 0.7780 - val_loss: 0.8068 - val_categorical_accuracy: 0.7172 - lr: 0.0010
# Epoch 4/30
# 635/635 [==============================] - 7s 11ms/step - loss: 0.4918 - categorical_accuracy: 0.8138 - val_loss: 0.9045 - val_categorical_accuracy: 0.7088 - lr: 0.0010
# Epoch 5/30
# 635/635 [==============================] - 8s 12ms/step - loss: 0.4236 - categorical_accuracy: 0.8421 - val_loss: 0.9850 - val_categorical_accuracy: 0.6959 - lr: 0.0010
# Epoch 6/30
# 635/635 [==============================] - 8s 13ms/step - loss: 0.3795 - categorical_accuracy: 0.8584 - val_loss: 1.0651 - val_categorical_accuracy: 0.6997 - lr: 0.0010
# Epoch 7/30
# 635/635 [==============================] - 8s 12ms/step - loss: 0.3411 - categorical_accuracy: 0.8718 - val_loss: 1.0686 - val_categorical_accuracy: 0.6979 - lr: 0.0010
# Epoch 8/30
# 635/635 [==============================] - 8s 12ms/step - loss: 0.3139 - categorical_accuracy: 0.8835 - val_loss: 1.1363 - val_categorical_accuracy: 0.7010 - lr: 0.0010
# Epoch 9/30
# 635/635 [==============================] - 8s 12ms/step - loss: 0.2893 - categorical_accuracy: 0.8936 - val_loss: 1.1797 - val_categorical_accuracy: 0.6919 - lr: 0.0010
# Epoch 10/30
# 635/635 [==============================] - 8s 12ms/step - loss: 0.2742 - categorical_accuracy: 0.9006 - val_loss: 1.2102 - val_categorical_accuracy: 0.6970 - lr: 0.0010
# Epoch 11/30
# 635/635 [==============================] - 8s 12ms/step - loss: 0.2471 - categorical_accuracy: 0.9078 - val_loss: 1.2569 - val_categorical_accuracy: 0.6950 - lr: 9.2312e-04
#
# Evaluating model performance on unseen data (test data):
#
# 79/79 [==============================] - 0s 3ms/step - loss: 1.2737 - categorical_accuracy: 0.6764
#
# test loss: 1.27374, test accuracy:'               '0.67644
# [Endothelial cell] Trial 4: test_acc=0.6764, test_loss=1.2737
# Model: "deepscore"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization_12 (Ba  (None, 1653)              6612
#  tchNormalization)
#
#  dense512 (Dense)            (None, 512)               846848
#
#  dropout_8 (Dropout)         (None, 512)               0
#
#  batch_normalization_13 (Ba  (None, 512)               2048
#  tchNormalization)
#
#  dense256 (Dense)            (None, 256)               131328
#
#  dropout_9 (Dropout)         (None, 256)               0
#
#  batch_normalization_14 (Ba  (None, 256)               1024
#  tchNormalization)
#
#  output (Dense)              (None, 8)                 2056
#
# =================================================================
# Total params: 989916 (3.78 MB)
# Trainable params: 985074 (3.76 MB)
# Non-trainable params: 4842 (18.91 KB)
# _________________________________________________________________
# Epoch 1/60
# 635/635 [==============================] - 18s 27ms/step - loss: 0.9258 - categorical_accuracy: 0.6652 - val_loss: 0.7485 - val_categorical_accuracy: 0.7247 - lr: 0.0010
# Epoch 2/60
# 635/635 [==============================] - 16s 25ms/step - loss: 0.6922 - categorical_accuracy: 0.7430 - val_loss: 0.7706 - val_categorical_accuracy: 0.7274 - lr: 0.0010
# Epoch 3/60
# 635/635 [==============================] - 7s 12ms/step - loss: 0.5922 - categorical_accuracy: 0.7779 - val_loss: 0.8061 - val_categorical_accuracy: 0.7179 - lr: 0.0010
# Epoch 4/60
# 635/635 [==============================] - 7s 12ms/step - loss: 0.4928 - categorical_accuracy: 0.8128 - val_loss: 0.9005 - val_categorical_accuracy: 0.7061 - lr: 0.0010
# Epoch 5/60
# 635/635 [==============================] - 8s 12ms/step - loss: 0.4219 - categorical_accuracy: 0.8416 - val_loss: 0.9697 - val_categorical_accuracy: 0.6990 - lr: 0.0010
# Epoch 6/60
# 635/635 [==============================] - 8s 12ms/step - loss: 0.3762 - categorical_accuracy: 0.8582 - val_loss: 1.0343 - val_categorical_accuracy: 0.6957 - lr: 0.0010
#
# Evaluating model performance on unseen data (test data):
#
# 79/79 [==============================] - 0s 3ms/step - loss: 1.0790 - categorical_accuracy: 0.6898
#
# test loss: 1.079, test accuracy:'               '0.68981
# [Endothelial cell] Trial 5: test_acc=0.6898, test_loss=1.0790
# Model: "deepscore"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization_15 (Ba  (None, 1653)              6612
#  tchNormalization)
#
#  dense512 (Dense)            (None, 512)               846848
#
#  dropout_10 (Dropout)        (None, 512)               0
#
#  batch_normalization_16 (Ba  (None, 512)               2048
#  tchNormalization)
#
#  dense256 (Dense)            (None, 256)               131328
#
#  dropout_11 (Dropout)        (None, 256)               0
#
#  batch_normalization_17 (Ba  (None, 256)               1024
#  tchNormalization)
#
#  output (Dense)              (None, 8)                 2056
#
# =================================================================
# Total params: 989916 (3.78 MB)
# Trainable params: 985074 (3.76 MB)
# Non-trainable params: 4842 (18.91 KB)
# _________________________________________________________________
# Epoch 1/60
# 635/635 [==============================] - 9s 12ms/step - loss: 0.9164 - categorical_accuracy: 0.6717 - val_loss: 0.7595 - val_categorical_accuracy: 0.7298 - lr: 0.0010
# Epoch 2/60
# 635/635 [==============================] - 8s 12ms/step - loss: 0.6905 - categorical_accuracy: 0.7427 - val_loss: 0.7548 - val_categorical_accuracy: 0.7225 - lr: 0.0010
# Epoch 3/60
# 635/635 [==============================] - 8s 13ms/step - loss: 0.5921 - categorical_accuracy: 0.7785 - val_loss: 0.7986 - val_categorical_accuracy: 0.7181 - lr: 0.0010
# Epoch 4/60
# 635/635 [==============================] - 20s 32ms/step - loss: 0.4947 - categorical_accuracy: 0.8124 - val_loss: 0.8984 - val_categorical_accuracy: 0.7070 - lr: 0.0010
# Epoch 5/60
# 635/635 [==============================] - 11s 17ms/step - loss: 0.4245 - categorical_accuracy: 0.8408 - val_loss: 0.9944 - val_categorical_accuracy: 0.6950 - lr: 0.0010
# Epoch 6/60
# 635/635 [==============================] - 7s 11ms/step - loss: 0.3777 - categorical_accuracy: 0.8596 - val_loss: 1.0539 - val_categorical_accuracy: 0.6984 - lr: 0.0010
# Epoch 7/60
# 635/635 [==============================] - 8s 12ms/step - loss: 0.3420 - categorical_accuracy: 0.8750 - val_loss: 1.0844 - val_categorical_accuracy: 0.6988 - lr: 0.0010
#
# Evaluating model performance on unseen data (test data):
#
# 79/79 [==============================] - 0s 3ms/step - loss: 1.0914 - categorical_accuracy: 0.6894
#
# test loss: 1.09137, test accuracy:'               '0.68941
# [Endothelial cell] Trial 6: test_acc=0.6894, test_loss=1.0914
# Model: "deepscore"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization_18 (Ba  (None, 1653)              6612
#  tchNormalization)
#
#  dense512 (Dense)            (None, 512)               846848
#
#  dropout_12 (Dropout)        (None, 512)               0
#
#  batch_normalization_19 (Ba  (None, 512)               2048
#  tchNormalization)
#
#  dense256 (Dense)            (None, 256)               131328
#
#  dropout_13 (Dropout)        (None, 256)               0
#
#  batch_normalization_20 (Ba  (None, 256)               1024
#  tchNormalization)
#
#  output (Dense)              (None, 8)                 2056
#
# =================================================================
# Total params: 989916 (3.78 MB)
# Trainable params: 985074 (3.76 MB)
# Non-trainable params: 4842 (18.91 KB)
# _________________________________________________________________
# Epoch 1/60
# 635/635 [==============================] - 9s 12ms/step - loss: 0.9262 - categorical_accuracy: 0.6673 - val_loss: 0.7467 - val_categorical_accuracy: 0.7332 - lr: 0.0010
# Epoch 2/60
# 635/635 [==============================] - 8s 12ms/step - loss: 0.6931 - categorical_accuracy: 0.7390 - val_loss: 0.7625 - val_categorical_accuracy: 0.7278 - lr: 0.0010
# Epoch 3/60
# 635/635 [==============================] - 8s 12ms/step - loss: 0.5939 - categorical_accuracy: 0.7775 - val_loss: 0.7869 - val_categorical_accuracy: 0.7203 - lr: 0.0010
# Epoch 4/60
# 635/635 [==============================] - 8s 12ms/step - loss: 0.4939 - categorical_accuracy: 0.8146 - val_loss: 0.8847 - val_categorical_accuracy: 0.7114 - lr: 0.0010
# Epoch 5/60
# 635/635 [==============================] - 8s 12ms/step - loss: 0.4236 - categorical_accuracy: 0.8411 - val_loss: 0.9680 - val_categorical_accuracy: 0.7026 - lr: 0.0010
# Epoch 6/60
# 635/635 [==============================] - 8s 12ms/step - loss: 0.3719 - categorical_accuracy: 0.8619 - val_loss: 1.0260 - val_categorical_accuracy: 0.6873 - lr: 0.0010
# Epoch 7/60
# 635/635 [==============================] - 8s 12ms/step - loss: 0.3420 - categorical_accuracy: 0.8728 - val_loss: 1.0769 - val_categorical_accuracy: 0.6968 - lr: 0.0010
# Epoch 8/60
# 635/635 [==============================] - 8s 12ms/step - loss: 0.3092 - categorical_accuracy: 0.8864 - val_loss: 1.0983 - val_categorical_accuracy: 0.6902 - lr: 0.0010
# Epoch 9/60
# 635/635 [==============================] - 7s 11ms/step - loss: 0.2867 - categorical_accuracy: 0.8950 - val_loss: 1.2068 - val_categorical_accuracy: 0.6833 - lr: 0.0010
# Epoch 10/60
# 635/635 [==============================] - 7s 12ms/step - loss: 0.2729 - categorical_accuracy: 0.9004 - val_loss: 1.2069 - val_categorical_accuracy: 0.6891 - lr: 0.0010
# Epoch 11/60
# 635/635 [==============================] - 8s 12ms/step - loss: 0.2552 - categorical_accuracy: 0.9084 - val_loss: 1.2073 - val_categorical_accuracy: 0.6877 - lr: 0.0010
#
# Evaluating model performance on unseen data (test data):
#
# 79/79 [==============================] - 0s 3ms/step - loss: 1.2452 - categorical_accuracy: 0.6838
#
# test loss: 1.24524, test accuracy:'               '0.68382
# [Endothelial cell] Trial 7: test_acc=0.6838, test_loss=1.2452
# Model: "deepscore"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization_21 (Ba  (None, 1653)              6612
#  tchNormalization)
#
#  dense512 (Dense)            (None, 512)               846848
#
#  dropout_14 (Dropout)        (None, 512)               0
#
#  batch_normalization_22 (Ba  (None, 512)               2048
#  tchNormalization)
#
#  dense256 (Dense)            (None, 256)               131328
#
#  dropout_15 (Dropout)        (None, 256)               0
#
#  batch_normalization_23 (Ba  (None, 256)               1024
#  tchNormalization)
#
#  output (Dense)              (None, 8)                 2056
#
# =================================================================
# Total params: 989916 (3.78 MB)
# Trainable params: 985074 (3.76 MB)
# Non-trainable params: 4842 (18.91 KB)
# _________________________________________________________________
# Epoch 1/60
# 635/635 [==============================] - 9s 12ms/step - loss: 0.9239 - categorical_accuracy: 0.6672 - val_loss: 0.7492 - val_categorical_accuracy: 0.7270 - lr: 0.0010
# Epoch 2/60
# 635/635 [==============================] - 7s 12ms/step - loss: 0.6924 - categorical_accuracy: 0.7420 - val_loss: 0.7704 - val_categorical_accuracy: 0.7194 - lr: 0.0010
# Epoch 3/60
# 635/635 [==============================] - 7s 12ms/step - loss: 0.5911 - categorical_accuracy: 0.7779 - val_loss: 0.8028 - val_categorical_accuracy: 0.7159 - lr: 0.0010
# Epoch 4/60
# 635/635 [==============================] - 7s 12ms/step - loss: 0.4966 - categorical_accuracy: 0.8112 - val_loss: 0.8944 - val_categorical_accuracy: 0.7035 - lr: 0.0010
# Epoch 5/60
# 635/635 [==============================] - 8s 13ms/step - loss: 0.4229 - categorical_accuracy: 0.8415 - val_loss: 0.9773 - val_categorical_accuracy: 0.6944 - lr: 0.0010
# Epoch 6/60
# 635/635 [==============================] - 8s 12ms/step - loss: 0.3705 - categorical_accuracy: 0.8614 - val_loss: 1.0625 - val_categorical_accuracy: 0.6948 - lr: 0.0010
# Epoch 7/60
# 635/635 [==============================] - 7s 12ms/step - loss: 0.3367 - categorical_accuracy: 0.8746 - val_loss: 1.1097 - val_categorical_accuracy: 0.6855 - lr: 0.0010
# Epoch 8/60
# 635/635 [==============================] - 7s 12ms/step - loss: 0.3095 - categorical_accuracy: 0.8872 - val_loss: 1.1264 - val_categorical_accuracy: 0.6953 - lr: 0.0010
# Epoch 9/60
# 635/635 [==============================] - 8s 13ms/step - loss: 0.2821 - categorical_accuracy: 0.8961 - val_loss: 1.2205 - val_categorical_accuracy: 0.6882 - lr: 0.0010
# Epoch 10/60
# 635/635 [==============================] - 8s 12ms/step - loss: 0.2663 - categorical_accuracy: 0.9022 - val_loss: 1.1861 - val_categorical_accuracy: 0.6871 - lr: 0.0010
# Epoch 11/60
# 635/635 [==============================] - 8s 12ms/step - loss: 0.2380 - categorical_accuracy: 0.9130 - val_loss: 1.2608 - val_categorical_accuracy: 0.6877 - lr: 9.2312e-04
#
# Evaluating model performance on unseen data (test data):
#
# 79/79 [==============================] - 0s 3ms/step - loss: 1.1979 - categorical_accuracy: 0.6934
#
# test loss: 1.19794, test accuracy:'               '0.6934
# [Endothelial cell] Trial 8: test_acc=0.6934, test_loss=1.1979
# Model: "deepscore"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization_24 (Ba  (None, 1653)              6612
#  tchNormalization)
#
#  dense512 (Dense)            (None, 512)               846848
#
#  dropout_16 (Dropout)        (None, 512)               0
#
#  batch_normalization_25 (Ba  (None, 512)               2048
#  tchNormalization)
#
#  dense256 (Dense)            (None, 256)               131328
#
#  dropout_17 (Dropout)        (None, 256)               0
#
#  batch_normalization_26 (Ba  (None, 256)               1024
#  tchNormalization)
#
#  output (Dense)              (None, 8)                 2056
#
# =================================================================
# Total params: 989916 (3.78 MB)
# Trainable params: 985074 (3.76 MB)
# Non-trainable params: 4842 (18.91 KB)
# _________________________________________________________________
# Epoch 1/30
# 318/318 [==============================] - 6s 16ms/step - loss: 0.9308 - categorical_accuracy: 0.6674 - val_loss: 0.7788 - val_categorical_accuracy: 0.7152 - lr: 0.0010
# Epoch 2/30
# 318/318 [==============================] - 5s 14ms/step - loss: 0.6597 - categorical_accuracy: 0.7540 - val_loss: 0.7432 - val_categorical_accuracy: 0.7292 - lr: 0.0010
# Epoch 3/30
# 318/318 [==============================] - 5s 16ms/step - loss: 0.5455 - categorical_accuracy: 0.7972 - val_loss: 0.7945 - val_categorical_accuracy: 0.7150 - lr: 0.0010
# Epoch 4/30
# 318/318 [==============================] - 5s 14ms/step - loss: 0.4353 - categorical_accuracy: 0.8378 - val_loss: 0.8802 - val_categorical_accuracy: 0.7130 - lr: 0.0010
# Epoch 5/30
# 318/318 [==============================] - 5s 14ms/step - loss: 0.3142 - categorical_accuracy: 0.8853 - val_loss: 1.0107 - val_categorical_accuracy: 0.7041 - lr: 0.0010
# Epoch 6/30
# 318/318 [==============================] - 5s 15ms/step - loss: 0.2288 - categorical_accuracy: 0.9177 - val_loss: 1.1335 - val_categorical_accuracy: 0.6948 - lr: 0.0010
# Epoch 7/30
# 318/318 [==============================] - 5s 15ms/step - loss: 0.1815 - categorical_accuracy: 0.9361 - val_loss: 1.2650 - val_categorical_accuracy: 0.7019 - lr: 0.0010
#
# Evaluating model performance on unseen data (test data):
#
# 40/40 [==============================] - 0s 3ms/step - loss: 1.3070 - categorical_accuracy: 0.6902
#
# test loss: 1.30702, test accuracy:'               '0.69021
# [Endothelial cell] Trial 9: test_acc=0.6902, test_loss=1.3070
# Model: "deepscore"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization_27 (Ba  (None, 1653)              6612
#  tchNormalization)
#
#  dense512 (Dense)            (None, 512)               846848
#
#  dropout_18 (Dropout)        (None, 512)               0
#
#  batch_normalization_28 (Ba  (None, 512)               2048
#  tchNormalization)
#
#  dense256 (Dense)            (None, 256)               131328
#
#  dropout_19 (Dropout)        (None, 256)               0
#
#  batch_normalization_29 (Ba  (None, 256)               1024
#  tchNormalization)
#
#  output (Dense)              (None, 8)                 2056
#
# =================================================================
# Total params: 989916 (3.78 MB)
# Trainable params: 985074 (3.76 MB)
# Non-trainable params: 4842 (18.91 KB)
# _________________________________________________________________
# Epoch 1/30
# 318/318 [==============================] - 6s 15ms/step - loss: 0.9277 - categorical_accuracy: 0.6662 - val_loss: 0.7747 - val_categorical_accuracy: 0.7207 - lr: 0.0010
# Epoch 2/30
# 318/318 [==============================] - 5s 14ms/step - loss: 0.6585 - categorical_accuracy: 0.7547 - val_loss: 0.7455 - val_categorical_accuracy: 0.7281 - lr: 0.0010
# Epoch 3/30
# 318/318 [==============================] - 5s 14ms/step - loss: 0.5475 - categorical_accuracy: 0.7961 - val_loss: 0.7885 - val_categorical_accuracy: 0.7258 - lr: 0.0010
# Epoch 4/30
# 318/318 [==============================] - 5s 15ms/step - loss: 0.4312 - categorical_accuracy: 0.8390 - val_loss: 0.8895 - val_categorical_accuracy: 0.7139 - lr: 0.0010
# Epoch 5/30
# 318/318 [==============================] - 5s 14ms/step - loss: 0.3147 - categorical_accuracy: 0.8846 - val_loss: 0.9981 - val_categorical_accuracy: 0.7119 - lr: 0.0010
# Epoch 6/30
# 318/318 [==============================] - 5s 15ms/step - loss: 0.2242 - categorical_accuracy: 0.9200 - val_loss: 1.1465 - val_categorical_accuracy: 0.7032 - lr: 0.0010
# Epoch 7/30
# 318/318 [==============================] - 5s 15ms/step - loss: 0.1853 - categorical_accuracy: 0.9335 - val_loss: 1.2428 - val_categorical_accuracy: 0.7004 - lr: 0.0010
#
# Evaluating model performance on unseen data (test data):
#
# 40/40 [==============================] - 0s 3ms/step - loss: 1.2508 - categorical_accuracy: 0.6874
#
# test loss: 1.25076, test accuracy:'               '0.68741
# [Endothelial cell] Trial 10: test_acc=0.6874, test_loss=1.2508
# Model: "deepscore"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization_30 (Ba  (None, 1653)              6612
#  tchNormalization)
#
#  dense512 (Dense)            (None, 512)               846848
#
#  dropout_20 (Dropout)        (None, 512)               0
#
#  batch_normalization_31 (Ba  (None, 512)               2048
#  tchNormalization)
#
#  dense256 (Dense)            (None, 256)               131328
#
#  dropout_21 (Dropout)        (None, 256)               0
#
#  batch_normalization_32 (Ba  (None, 256)               1024
#  tchNormalization)
#
#  output (Dense)              (None, 8)                 2056
#
# =================================================================
# Total params: 989916 (3.78 MB)
# Trainable params: 985074 (3.76 MB)
# Non-trainable params: 4842 (18.91 KB)
# _________________________________________________________________
# Epoch 1/30
# 318/318 [==============================] - 6s 15ms/step - loss: 0.9231 - categorical_accuracy: 0.6673 - val_loss: 0.7596 - val_categorical_accuracy: 0.7238 - lr: 0.0010
# Epoch 2/30
# 318/318 [==============================] - 5s 14ms/step - loss: 0.6576 - categorical_accuracy: 0.7569 - val_loss: 0.7499 - val_categorical_accuracy: 0.7281 - lr: 0.0010
# Epoch 3/30
# 318/318 [==============================] - 5s 15ms/step - loss: 0.5412 - categorical_accuracy: 0.7998 - val_loss: 0.8015 - val_categorical_accuracy: 0.7159 - lr: 0.0010
# Epoch 4/30
# 318/318 [==============================] - 5s 15ms/step - loss: 0.4252 - categorical_accuracy: 0.8426 - val_loss: 0.8875 - val_categorical_accuracy: 0.7150 - lr: 0.0010
# Epoch 5/30
# 318/318 [==============================] - 5s 15ms/step - loss: 0.3083 - categorical_accuracy: 0.8875 - val_loss: 1.0365 - val_categorical_accuracy: 0.7059 - lr: 0.0010
# Epoch 6/30
# 318/318 [==============================] - 5s 15ms/step - loss: 0.2244 - categorical_accuracy: 0.9187 - val_loss: 1.1630 - val_categorical_accuracy: 0.7015 - lr: 0.0010
# Epoch 7/30
# 318/318 [==============================] - 5s 15ms/step - loss: 0.1823 - categorical_accuracy: 0.9342 - val_loss: 1.2680 - val_categorical_accuracy: 0.7055 - lr: 0.0010
# Epoch 8/30
# 318/318 [==============================] - 5s 15ms/step - loss: 0.1670 - categorical_accuracy: 0.9396 - val_loss: 1.3345 - val_categorical_accuracy: 0.7023 - lr: 0.0010
# Epoch 9/30
# 318/318 [==============================] - 5s 15ms/step - loss: 0.1493 - categorical_accuracy: 0.9457 - val_loss: 1.3636 - val_categorical_accuracy: 0.6975 - lr: 0.0010
# Epoch 10/30
# 318/318 [==============================] - 5s 15ms/step - loss: 0.1492 - categorical_accuracy: 0.9470 - val_loss: 1.3960 - val_categorical_accuracy: 0.6888 - lr: 0.0010
# Epoch 11/30
# 318/318 [==============================] - 5s 15ms/step - loss: 0.1364 - categorical_accuracy: 0.9507 - val_loss: 1.4377 - val_categorical_accuracy: 0.6868 - lr: 0.0010
# Epoch 12/30
# 318/318 [==============================] - 5s 15ms/step - loss: 0.1364 - categorical_accuracy: 0.9506 - val_loss: 1.4362 - val_categorical_accuracy: 0.6984 - lr: 0.0010
#
# Evaluating model performance on unseen data (test data):
#
# 40/40 [==============================] - 0s 4ms/step - loss: 1.4643 - categorical_accuracy: 0.6886
#
# test loss: 1.4643, test accuracy:'               '0.68861
# [Endothelial cell] Trial 11: test_acc=0.6886, test_loss=1.4643
# Model: "deepscore"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization_33 (Ba  (None, 1653)              6612
#  tchNormalization)
#
#  dense512 (Dense)            (None, 512)               846848
#
#  dropout_22 (Dropout)        (None, 512)               0
#
#  batch_normalization_34 (Ba  (None, 512)               2048
#  tchNormalization)
#
#  dense256 (Dense)            (None, 256)               131328
#
#  dropout_23 (Dropout)        (None, 256)               0
#
#  batch_normalization_35 (Ba  (None, 256)               1024
#  tchNormalization)
#
#  output (Dense)              (None, 8)                 2056
#
# =================================================================
# Total params: 989916 (3.78 MB)
# Trainable params: 985074 (3.76 MB)
# Non-trainable params: 4842 (18.91 KB)
# _________________________________________________________________
# Epoch 1/30
# 318/318 [==============================] - 6s 15ms/step - loss: 0.9250 - categorical_accuracy: 0.6653 - val_loss: 0.7699 - val_categorical_accuracy: 0.7165 - lr: 0.0010
# Epoch 2/30
# 318/318 [==============================] - 5s 15ms/step - loss: 0.6572 - categorical_accuracy: 0.7547 - val_loss: 0.7485 - val_categorical_accuracy: 0.7245 - lr: 0.0010
# Epoch 3/30
# 318/318 [==============================] - 5s 15ms/step - loss: 0.5447 - categorical_accuracy: 0.7958 - val_loss: 0.8005 - val_categorical_accuracy: 0.7145 - lr: 0.0010
# Epoch 4/30
# 318/318 [==============================] - 5s 15ms/step - loss: 0.4268 - categorical_accuracy: 0.8414 - val_loss: 0.8773 - val_categorical_accuracy: 0.7112 - lr: 0.0010
# Epoch 5/30
# 318/318 [==============================] - 5s 15ms/step - loss: 0.3202 - categorical_accuracy: 0.8819 - val_loss: 1.0292 - val_categorical_accuracy: 0.7039 - lr: 0.0010
# Epoch 6/30
# 318/318 [==============================] - 5s 15ms/step - loss: 0.2259 - categorical_accuracy: 0.9183 - val_loss: 1.1324 - val_categorical_accuracy: 0.6992 - lr: 0.0010
# Epoch 7/30
# 318/318 [==============================] - 5s 15ms/step - loss: 0.1823 - categorical_accuracy: 0.9346 - val_loss: 1.2455 - val_categorical_accuracy: 0.6979 - lr: 0.0010
# Epoch 8/30
# 318/318 [==============================] - 5s 15ms/step - loss: 0.1697 - categorical_accuracy: 0.9383 - val_loss: 1.3068 - val_categorical_accuracy: 0.6973 - lr: 0.0010
# Epoch 9/30
# 318/318 [==============================] - 5s 15ms/step - loss: 0.1552 - categorical_accuracy: 0.9441 - val_loss: 1.3389 - val_categorical_accuracy: 0.6961 - lr: 0.0010
# Epoch 10/30
# 318/318 [==============================] - 5s 15ms/step - loss: 0.1538 - categorical_accuracy: 0.9439 - val_loss: 1.4048 - val_categorical_accuracy: 0.6820 - lr: 0.0010
# Epoch 11/30
# 318/318 [==============================] - 5s 15ms/step - loss: 0.1245 - categorical_accuracy: 0.9560 - val_loss: 1.4394 - val_categorical_accuracy: 0.6917 - lr: 9.2312e-04
# Epoch 12/30
# 318/318 [==============================] - 5s 14ms/step - loss: 0.1069 - categorical_accuracy: 0.9620 - val_loss: 1.4981 - val_categorical_accuracy: 0.6866 - lr: 8.5214e-04
#
# Evaluating model performance on unseen data (test data):
#
# 40/40 [==============================] - 0s 3ms/step - loss: 1.5014 - categorical_accuracy: 0.6890
#
# test loss: 1.50142, test accuracy:'               '0.68901
# [Endothelial cell] Trial 12: test_acc=0.6890, test_loss=1.5014
# Model: "deepscore"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization_36 (Ba  (None, 1653)              6612
#  tchNormalization)
#
#  dense512 (Dense)            (None, 512)               846848
#
#  dropout_24 (Dropout)        (None, 512)               0
#
#  batch_normalization_37 (Ba  (None, 512)               2048
#  tchNormalization)
#
#  dense256 (Dense)            (None, 256)               131328
#
#  dropout_25 (Dropout)        (None, 256)               0
#
#  batch_normalization_38 (Ba  (None, 256)               1024
#  tchNormalization)
#
#  output (Dense)              (None, 8)                 2056
#
# =================================================================
# Total params: 989916 (3.78 MB)
# Trainable params: 985074 (3.76 MB)
# Non-trainable params: 4842 (18.91 KB)
# _________________________________________________________________
# Epoch 1/60
# 318/318 [==============================] - 6s 15ms/step - loss: 0.9306 - categorical_accuracy: 0.6652 - val_loss: 0.7678 - val_categorical_accuracy: 0.7185 - lr: 0.0010
# Epoch 2/60
# 318/318 [==============================] - 5s 15ms/step - loss: 0.6544 - categorical_accuracy: 0.7551 - val_loss: 0.7605 - val_categorical_accuracy: 0.7243 - lr: 0.0010
# Epoch 3/60
# 318/318 [==============================] - 5s 15ms/step - loss: 0.5430 - categorical_accuracy: 0.7983 - val_loss: 0.8031 - val_categorical_accuracy: 0.7137 - lr: 0.0010
# Epoch 4/60
# 318/318 [==============================] - 5s 15ms/step - loss: 0.4318 - categorical_accuracy: 0.8397 - val_loss: 0.8957 - val_categorical_accuracy: 0.7063 - lr: 0.0010
# Epoch 5/60
# 318/318 [==============================] - 5s 15ms/step - loss: 0.3161 - categorical_accuracy: 0.8834 - val_loss: 1.0077 - val_categorical_accuracy: 0.7043 - lr: 0.0010
# Epoch 6/60
# 318/318 [==============================] - 5s 15ms/step - loss: 0.2294 - categorical_accuracy: 0.9173 - val_loss: 1.1420 - val_categorical_accuracy: 0.6981 - lr: 0.0010
# Epoch 7/60
# 318/318 [==============================] - 5s 15ms/step - loss: 0.1796 - categorical_accuracy: 0.9357 - val_loss: 1.2327 - val_categorical_accuracy: 0.6941 - lr: 0.0010
#
# Evaluating model performance on unseen data (test data):
#
# 40/40 [==============================] - 0s 4ms/step - loss: 1.2611 - categorical_accuracy: 0.6940
#
# test loss: 1.26105, test accuracy:'               '0.694
# [Endothelial cell] Trial 13: test_acc=0.6940, test_loss=1.2611
# Model: "deepscore"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization_39 (Ba  (None, 1653)              6612
#  tchNormalization)
#
#  dense512 (Dense)            (None, 512)               846848
#
#  dropout_26 (Dropout)        (None, 512)               0
#
#  batch_normalization_40 (Ba  (None, 512)               2048
#  tchNormalization)
#
# ...
#
# Evaluating model performance on unseen data (test data):
#
# 79/79 [==============================] - 0s 5ms/step - loss: 1.4036 - categorical_accuracy: 0.7159
#
# test loss: 1.40357, test accuracy:'               '0.71594
# [Endothelial cell] Trial 263: test_acc=0.7159, test_loss=1.4036
# Model: "deepscore"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization_789 (B  (None, 1653)              6612
#  atchNormalization)
#
#  dense512 (Dense)            (None, 512)               846848
#
#  dropout_526 (Dropout)       (None, 512)               0
#
#  batch_normalization_790 (B  (None, 512)               2048
#  atchNormalization)
#
#  dense256 (Dense)            (None, 256)               131328
#
#  dropout_527 (Dropout)       (None, 256)               0
#
#  batch_normalization_791 (B  (None, 256)               1024
#  atchNormalization)
#
#  output (Dense)              (None, 8)                 2056
#
# =================================================================
# Total params: 989916 (3.78 MB)
# Trainable params: 985074 (3.76 MB)
# Non-trainable params: 4842 (18.91 KB)
# _________________________________________________________________
# Epoch 1/60
# 635/635 [==============================] - 14s 20ms/step - loss: 1.8735 - categorical_accuracy: 0.6628 - val_loss: 1.4539 - val_categorical_accuracy: 0.7363 - lr: 0.0010
# Epoch 2/60
# 635/635 [==============================] - 13s 20ms/step - loss: 1.3371 - categorical_accuracy: 0.7221 - val_loss: 1.2231 - val_categorical_accuracy: 0.7312 - lr: 0.0010
# Epoch 3/60
# 635/635 [==============================] - 13s 20ms/step - loss: 1.1649 - categorical_accuracy: 0.7281 - val_loss: 1.1486 - val_categorical_accuracy: 0.7272 - lr: 0.0010
# Epoch 4/60
# 635/635 [==============================] - 13s 20ms/step - loss: 1.1175 - categorical_accuracy: 0.7361 - val_loss: 1.1417 - val_categorical_accuracy: 0.7307 - lr: 0.0010
# Epoch 5/60
# 635/635 [==============================] - 13s 20ms/step - loss: 1.1149 - categorical_accuracy: 0.7404 - val_loss: 1.2007 - val_categorical_accuracy: 0.7174 - lr: 0.0010
# Epoch 6/60
# 635/635 [==============================] - 12s 19ms/step - loss: 1.1360 - categorical_accuracy: 0.7441 - val_loss: 1.2251 - val_categorical_accuracy: 0.7243 - lr: 0.0010
# Epoch 7/60
# 635/635 [==============================] - 12s 19ms/step - loss: 1.1512 - categorical_accuracy: 0.7525 - val_loss: 1.2616 - val_categorical_accuracy: 0.7247 - lr: 0.0010
# Epoch 8/60
# 635/635 [==============================] - 14s 22ms/step - loss: 1.1648 - categorical_accuracy: 0.7581 - val_loss: 1.2935 - val_categorical_accuracy: 0.7263 - lr: 0.0010
# Epoch 9/60
# 635/635 [==============================] - 14s 22ms/step - loss: 1.1774 - categorical_accuracy: 0.7658 - val_loss: 1.3273 - val_categorical_accuracy: 0.7252 - lr: 0.0010
# Epoch 10/60
# 635/635 [==============================] - 13s 21ms/step - loss: 1.1754 - categorical_accuracy: 0.7693 - val_loss: 1.3395 - val_categorical_accuracy: 0.7210 - lr: 0.0010
# Epoch 11/60
# 635/635 [==============================] - 13s 21ms/step - loss: 1.1459 - categorical_accuracy: 0.7826 - val_loss: 1.3610 - val_categorical_accuracy: 0.7267 - lr: 9.2312e-04
# Epoch 12/60
# 635/635 [==============================] - 13s 20ms/step - loss: 1.1192 - categorical_accuracy: 0.7932 - val_loss: 1.3742 - val_categorical_accuracy: 0.7090 - lr: 8.5214e-04
# Epoch 13/60
# 635/635 [==============================] - 13s 21ms/step - loss: 1.0711 - categorical_accuracy: 0.8091 - val_loss: 1.3991 - val_categorical_accuracy: 0.7159 - lr: 7.8663e-04
# Epoch 14/60
# 635/635 [==============================] - 14s 22ms/step - loss: 1.0381 - categorical_accuracy: 0.8205 - val_loss: 1.4452 - val_categorical_accuracy: 0.7032 - lr: 7.2615e-04
#
# Evaluating model performance on unseen data (test data):
#
# 79/79 [==============================] - 0s 5ms/step - loss: 1.4285 - categorical_accuracy: 0.7098
#
# test loss: 1.42854, test accuracy:'               '0.70975
# [Endothelial cell] Trial 264: test_acc=0.7098, test_loss=1.4285
# Model: "deepscore"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization_792 (B  (None, 1653)              6612
#  atchNormalization)
#
#  dense512 (Dense)            (None, 512)               846848
#
#  dropout_528 (Dropout)       (None, 512)               0
#
#  batch_normalization_793 (B  (None, 512)               2048
#  atchNormalization)
#
#  dense256 (Dense)            (None, 256)               131328
#
#  dropout_529 (Dropout)       (None, 256)               0
#
#  batch_normalization_794 (B  (None, 256)               1024
#  atchNormalization)
#
#  output (Dense)              (None, 8)                 2056
#
# =================================================================
# Total params: 989916 (3.78 MB)
# Trainable params: 985074 (3.76 MB)
# Non-trainable params: 4842 (18.91 KB)
# _________________________________________________________________
# Epoch 1/30
# 318/318 [==============================] - 9s 23ms/step - loss: 1.9203 - categorical_accuracy: 0.6585 - val_loss: 1.5358 - val_categorical_accuracy: 0.7305 - lr: 0.0010
# Epoch 2/30
# 318/318 [==============================] - 8s 24ms/step - loss: 1.3740 - categorical_accuracy: 0.7348 - val_loss: 1.2826 - val_categorical_accuracy: 0.7270 - lr: 0.0010
# Epoch 3/30
# 318/318 [==============================] - 10s 30ms/step - loss: 1.1537 - categorical_accuracy: 0.7547 - val_loss: 1.1978 - val_categorical_accuracy: 0.7241 - lr: 0.0010
# Epoch 4/30
# 318/318 [==============================] - 9s 27ms/step - loss: 1.0592 - categorical_accuracy: 0.7672 - val_loss: 1.1876 - val_categorical_accuracy: 0.7261 - lr: 0.0010
# Epoch 5/30
# 318/318 [==============================] - 10s 31ms/step - loss: 1.0341 - categorical_accuracy: 0.7810 - val_loss: 1.2429 - val_categorical_accuracy: 0.7207 - lr: 0.0010
# Epoch 6/30
# 318/318 [==============================] - 10s 30ms/step - loss: 1.0283 - categorical_accuracy: 0.7967 - val_loss: 1.3258 - val_categorical_accuracy: 0.7083 - lr: 0.0010
# Epoch 7/30
# 318/318 [==============================] - 9s 28ms/step - loss: 1.0328 - categorical_accuracy: 0.8158 - val_loss: 1.3891 - val_categorical_accuracy: 0.7139 - lr: 0.0010
# Epoch 8/30
# 318/318 [==============================] - 7s 21ms/step - loss: 1.0403 - categorical_accuracy: 0.8283 - val_loss: 1.4499 - val_categorical_accuracy: 0.7181 - lr: 0.0010
# Epoch 9/30
# 318/318 [==============================] - 7s 21ms/step - loss: 1.0446 - categorical_accuracy: 0.8424 - val_loss: 1.5281 - val_categorical_accuracy: 0.7008 - lr: 0.0010
#
# Evaluating model performance on unseen data (test data):
#
# 40/40 [==============================] - 0s 5ms/step - loss: 1.5324 - categorical_accuracy: 0.6990
#
# test loss: 1.53236, test accuracy:'               '0.69898
# [Endothelial cell] Trial 265: test_acc=0.6990, test_loss=1.5324
# Model: "deepscore"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization_795 (B  (None, 1653)              6612
#  atchNormalization)
#
#  dense512 (Dense)            (None, 512)               846848
#
#  dropout_530 (Dropout)       (None, 512)               0
#
#  batch_normalization_796 (B  (None, 512)               2048
#  atchNormalization)
#
#  dense256 (Dense)            (None, 256)               131328
#
#  dropout_531 (Dropout)       (None, 256)               0
#
#  batch_normalization_797 (B  (None, 256)               1024
#  atchNormalization)
#
#  output (Dense)              (None, 8)                 2056
#
# =================================================================
# Total params: 989916 (3.78 MB)
# Trainable params: 985074 (3.76 MB)
# Non-trainable params: 4842 (18.91 KB)
# _________________________________________________________________
# Epoch 1/30
# 318/318 [==============================] - 9s 23ms/step - loss: 1.9384 - categorical_accuracy: 0.6599 - val_loss: 1.5661 - val_categorical_accuracy: 0.7212 - lr: 0.0010
# Epoch 2/30
# 318/318 [==============================] - 6s 20ms/step - loss: 1.3853 - categorical_accuracy: 0.7356 - val_loss: 1.2830 - val_categorical_accuracy: 0.7356 - lr: 0.0010
# Epoch 3/30
# 318/318 [==============================] - 7s 21ms/step - loss: 1.1530 - categorical_accuracy: 0.7578 - val_loss: 1.2108 - val_categorical_accuracy: 0.7276 - lr: 0.0010
# Epoch 4/30
# 318/318 [==============================] - 6s 20ms/step - loss: 1.0626 - categorical_accuracy: 0.7672 - val_loss: 1.2006 - val_categorical_accuracy: 0.7238 - lr: 0.0010
# Epoch 5/30
# 318/318 [==============================] - 6s 20ms/step - loss: 1.0392 - categorical_accuracy: 0.7818 - val_loss: 1.2514 - val_categorical_accuracy: 0.7194 - lr: 0.0010
# Epoch 6/30
#  51/318 [===>..........................] - ETA: 5s - loss: 0.9049 - categorical_accuracy: 0.8373
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 215
#     213 tried += 1
#     214 cfg = deepcopy(cfg)
# --> 215 metrics, ds = evaluate_config(ref_use, ad_use, cell_type, cfg)
#     216 row = dict(cell_type=a, tried=tried, **cfg, **metrics)
#     217 results_all.append(row)
#
# Cell In[5], line 131, in evaluate_config(ref_py, adata, label_key, cfg)
#     129 sched = LR_SCHEDULERS[cfg["lr_sched_name"]]
#     130 # Train; we’ll read back the last val metrics from History
# --> 131 history = ds.train(
#     132     val_split=float(cfg["val_split"]),
#     133     earlystopping=True,
#     134     lr_scheduler=sched,
#     135     patience=int(cfg["patience"]),
#     136     training_report=True,   # returns [loss, acc] on test
#     137 )
#     138 # training_report returns "evaluation" = [test_loss, test_acc] according to the code. :contentReference[oaicite:4]{index=4}
#     139 test_loss, test_acc = float(history[0]), float(history[1])
#
# File ~/Documentos/CZI/MANUSCRIPT_PREP/REVIEWS/analysis/Deepscore/deepscore/deepscore.py:131, in DeepScore.train(self, val_split, earlystopping, lr_scheduler, patience, create_gif, gif_dataset, training_report)
#     128     else:
#     129         my_callbacks.append(PlotInference(self, gif_dataset))
# --> 131 self.model.fit(xtrain, ytrain, epochs=self.epochs,
#     132                batch_size=self.batch_size, validation_split=val_split,
#     133                verbose = True, callbacks=my_callbacks)
#     135 print("\nEvaluating model performance on unseen data (test data):\n")
#     136 evaluation = self.model.evaluate(xtest, ytest, batch_size=self.batch_size)
#
# File ~/.conda/envs/deepscore/lib/python3.8/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.conda/envs/deepscore/lib/python3.8/site-packages/keras/src/engine/training.py:1748, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1746 logs = tmp_logs
#    1747 end_step = step + data_handler.step_increment
# -> 1748 callbacks.on_train_batch_end(end_step, logs)
#    1749 if self.stop_training:
#    1750     break
#
# File ~/.conda/envs/deepscore/lib/python3.8/site-packages/keras/src/callbacks.py:475, in CallbackList.on_train_batch_end(self, batch, logs)
#     468 """Calls the `on_train_batch_end` methods of its callbacks.
#     469
#     470 Args:
#     471     batch: Integer, index of batch within the current epoch.
#     472     logs: Dict. Aggregated metric results up until this batch.
#     473 """
#     474 if self._should_call_train_batch_hooks:
# --> 475     self._call_batch_hook(ModeKeys.TRAIN, "end", batch, logs=logs)
#
# File ~/.conda/envs/deepscore/lib/python3.8/site-packages/keras/src/callbacks.py:322, in CallbackList._call_batch_hook(self, mode, hook, batch, logs)
#     320     self._call_batch_begin_hook(mode, batch, logs)
#     321 elif hook == "end":
# --> 322     self._call_batch_end_hook(mode, batch, logs)
#     323 else:
#     324     raise ValueError(
#     325         f"Unrecognized hook: {hook}. "
#     326         'Expected values are ["begin", "end"]'
#     327     )
#
# File ~/.conda/envs/deepscore/lib/python3.8/site-packages/keras/src/callbacks.py:345, in CallbackList._call_batch_end_hook(self, mode, batch, logs)
#     342     batch_time = time.time() - self._batch_start_time
#     343     self._batch_times.append(batch_time)
# --> 345 self._call_batch_hook_helper(hook_name, batch, logs)
#     347 if len(self._batch_times) >= self._num_batches_for_timing_check:
#     348     end_hook_name = hook_name
#
# File ~/.conda/envs/deepscore/lib/python3.8/site-packages/keras/src/callbacks.py:393, in CallbackList._call_batch_hook_helper(self, hook_name, batch, logs)
#     391 for callback in self.callbacks:
#     392     hook = getattr(callback, hook_name)
# --> 393     hook(batch, logs)
#     395 if self._check_timing:
#     396     if hook_name not in self._hook_times:
#
# File ~/.conda/envs/deepscore/lib/python3.8/site-packages/keras/src/callbacks.py:2824, in TensorBoard.on_train_batch_end(self, batch, logs)
#    2822 if isinstance(logs, dict):
#    2823     for name, value in logs.items():
# -> 2824         tf.summary.scalar("batch_" + name, value, step=self._train_step)
#    2826 if not self._should_trace:
#    2827     return
#
# KeyboardInterrupt:

# %%
## SET PARAMETERS
n_markers = 500 # Max number of markers to use per cell-type
overlapping = False # Parameter to control overlapping marker genes between cell types on the prediction.


# ref_py_save = ref_py.copy()

# for mod in ['scRNA','snRNA','scRNA5p']:
#     if os.path.exists(f'csv/Deepscore_HCA_l1_{mod}_CLEAN.csv'):
#         print(f'{mod} already exists!')

mod='HEART'

# adata.X = adata.layers['counts'].copy()


with open(f'markers_ds/{markers_filename}.pickle', 'rb') as handle:
    ranked_genes_populations = pickle.load(handle) 

if overlapping:
    selected_markers =[]
    for cell_type_ in ref_py.obs[cell_type].unique():
        cell_type_markers = []
        for marker in ranked_genes_populations['names'][cell_type_][:n_markers]:
            if marker in adata.var.index: 
                selected_markers.append(marker)
    selected_markers = set(selected_markers)

else:
    # Step 2: Store markers for each subset
    subset_markers_dict ={}
    for subset in ref_py.obs[cell_type].unique():
        subset_markers = ranked_genes_populations['names'][subset]
        subset_markers = [gene for gene in subset_markers if gene in adata.var.index]
        subset_markers_dict[subset] = set(subset_markers[:n_markers+100])

    # Step 3: Identify overlapping markers
    overlapping_markers = set()
    for subset, markers in subset_markers_dict.items():
        for other_subset, other_markers in subset_markers_dict.items():
            if subset != other_subset:
                overlapping_markers.update(markers.intersection(other_markers))

    # Step 4: Select markers for each subset, excluding overlapping markers
    marker_dict = {}
    for subset, markers in subset_markers_dict.items():
        unique_markers = [marker for marker in markers if marker not in overlapping_markers]
        marker_dict[subset] = unique_markers[:n_markers]  # Select up to TOP n_markers
    selected_markers = [marker for subset in marker_dict for marker in marker_dict[subset]]



    sc.pp.normalize_total(adata, target_sum=1e4)
    sc.pp.log1p(adata)


    # Subset the data to the selected markers

    ref_py = ref_py[:, list(selected_markers)].copy()
    adata = adata[:, list(selected_markers)].copy()

    len(selected_markers)

    sc.pp.scale(ref_py)
    sc.pp.scale(adata)

    ref_py.obs[cell_type] = ref_py.obs[cell_type].tolist()
    len(ref_py.obs[cell_type].unique())


    def scheduler(epoch, lr):
        if epoch < 10:
            return lr
        else:
            return lr * tf.math.exp(-0.1)


    n_feat = ref_py.shape[1]
    n_labs = len(ref_py.obs[cell_type].unique())

    ds = deepscore.DeepScore(hidden_nodes=[1024, 256],
                   n_features=n_feat, 
                   n_labels=n_labs,
                   epochs=30,
                   batch_size=128, 
                   activation="relu", 
                   dropout=True, 
                   dropout_rate=0.1,
                   batchnorm=True, 
                   lr=0.001,
                   weight_reg=True)




    import os
    os.environ["TF_GPU_ALLOCATOR"]="cuda_malloc_async"

    ds.set_reference(ref_py, label_by=cell_type, test_prop=0.1)

    ds.train(earlystopping=True, patience=10, lr_scheduler=scheduler,)
    # ds.model.save(f'models/deepscore') # In case you want to save the DS model

    prob_df, adata = ds.annotate(adata, pred_key='Deepscore_HCA',Unclassified = False,return_pred_matrix=True)

    # SAVE the RESULTS on csv
    adata.obs[['Deepscore_HCA','Deepscore_HCA_score']].to_csv(f'csv/Deepscore_HCA_l1_{mod}.csv')

    prob_df.to_csv(f'csv/prob_matrix/Deepscore_HCA_l1_{mod}_CLEAN.csv')
# Out:
# Model: "deepscore"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (Batch  (None, 1850)              7400
#  Normalization)
#
#  dense1024 (Dense)           (None, 1024)              1895424
#
#  dropout (Dropout)           (None, 1024)              0
#
#  batch_normalization_1 (Bat  (None, 1024)              4096
#  chNormalization)
#
#  dense256 (Dense)            (None, 256)               262400
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  batch_normalization_2 (Bat  (None, 256)               1024
#  chNormalization)
#
#  output (Dense)              (None, 5)                 1285
#
# =================================================================
# Total params: 2171629 (8.28 MB)
# Trainable params: 2165369 (8.26 MB)
# Non-trainable params: 6260 (24.45 KB)
# _________________________________________________________________
# 2025-08-14 17:43:00.721280: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 2488464600 exceeds 10% of free system memory.
# 2025-08-14 17:43:01.785926: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 2239617400 exceeds 10% of free system memory.
# Epoch 1/30
# 2365/2365 [==============================] - 59s 25ms/step - loss: 0.0065 - categorical_accuracy: 0.9979 - val_loss: 0.0029 - val_categorical_accuracy: 0.9991 - lr: 0.0010
# Epoch 2/30
# 2365/2365 [==============================] - 66s 28ms/step - loss: 0.0027 - categorical_accuracy: 0.9991 - val_loss: 0.0032 - val_categorical_accuracy: 0.9991 - lr: 0.0010
# Epoch 3/30
# 2365/2365 [==============================] - 66s 28ms/step - loss: 0.0020 - categorical_accuracy: 0.9993 - val_loss: 0.0034 - val_categorical_accuracy: 0.9990 - lr: 0.0010
# Epoch 4/30
# 2365/2365 [==============================] - 70s 30ms/step - loss: 0.0022 - categorical_accuracy: 0.9992 - val_loss: 0.0021 - val_categorical_accuracy: 0.9993 - lr: 0.0010
# Epoch 5/30
# 2365/2365 [==============================] - 70s 30ms/step - loss: 0.0021 - categorical_accuracy: 0.9993 - val_loss: 0.0028 - val_categorical_accuracy: 0.9993 - lr: 0.0010
# Epoch 6/30
# 2365/2365 [==============================] - 71s 30ms/step - loss: 0.0019 - categorical_accuracy: 0.9994 - val_loss: 0.0037 - val_categorical_accuracy: 0.9989 - lr: 0.0010
# Epoch 7/30
# 2365/2365 [==============================] - 76s 32ms/step - loss: 0.0018 - categorical_accuracy: 0.9994 - val_loss: 0.0026 - val_categorical_accuracy: 0.9992 - lr: 0.0010
# Epoch 8/30
# 2365/2365 [==============================] - 73s 31ms/step - loss: 0.0020 - categorical_accuracy: 0.9994 - val_loss: 0.0030 - val_categorical_accuracy: 0.9990 - lr: 0.0010
# Epoch 9/30
# 2365/2365 [==============================] - 73s 31ms/step - loss: 0.0014 - categorical_accuracy: 0.9995 - val_loss: 0.0031 - val_categorical_accuracy: 0.9990 - lr: 0.0010
# Epoch 10/30
# 2365/2365 [==============================] - 72s 30ms/step - loss: 0.0016 - categorical_accuracy: 0.9995 - val_loss: 0.0028 - val_categorical_accuracy: 0.9991 - lr: 0.0010
# Epoch 11/30
# 2365/2365 [==============================] - 73s 31ms/step - loss: 0.0015 - categorical_accuracy: 0.9995 - val_loss: 0.0025 - val_categorical_accuracy: 0.9991 - lr: 9.0484e-04
# Epoch 12/30
# 2365/2365 [==============================] - 72s 30ms/step - loss: 0.0011 - categorical_accuracy: 0.9996 - val_loss: 0.0033 - val_categorical_accuracy: 0.9991 - lr: 8.1873e-04
# Epoch 13/30
# 2365/2365 [==============================] - 71s 30ms/step - loss: 0.0011 - categorical_accuracy: 0.9997 - val_loss: 0.0024 - val_categorical_accuracy: 0.9993 - lr: 7.4082e-04
# Epoch 14/30
# 2365/2365 [==============================] - 71s 30ms/step - loss: 5.9901e-04 - categorical_accuracy: 0.9998 - val_loss: 0.0037 - val_categorical_accuracy: 0.9992 - lr: 6.7032e-04
#
# Evaluating model performance on unseen data (test data):
#
# 292/292 [==============================] - 2s 5ms/step - loss: 0.0060 - categorical_accuracy: 0.9987
#
# test loss: 0.00604, test accuracy:'               '0.99872
# 2025-08-14 17:59:28.342640: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 1699195400 exceeds 10% of free system memory.
#   10/1794 [..............................] - ETA: 11s
# 2025-08-14 17:59:29.499760: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 1699195400 exceeds 10% of free system memory.
# 1794/1794 [==============================] - 10s 5ms/step
